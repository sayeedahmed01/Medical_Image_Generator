# %%
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt

# %%
# Load the data
cases_df = pd.read_csv('data/scin_cases.csv')
labels_df = pd.read_csv('data/scin_labels.csv')

# %%
cases_df.head()
# Out:
#                case_id source release  year     age_group  \
# 0 -1000600354148496558   SCIN   1.0.0  2023   AGE_UNKNOWN
# 1 -1002039107727665188   SCIN   1.0.0  2023   AGE_UNKNOWN
# 2 -1003358831658393077   SCIN   1.0.0  2023  AGE_18_TO_29
# 3 -1003826561155964328   SCIN   1.0.0  2023   AGE_UNKNOWN
# 4 -1003844406100696311   SCIN   1.0.0  2023  AGE_40_TO_49
#
#            sex_at_birth fitzpatrick_skin_type  \
# 0  OTHER_OR_UNSPECIFIED                   NaN
# 1  OTHER_OR_UNSPECIFIED                   NaN
# 2                  MALE       NONE_IDENTIFIED
# 3  OTHER_OR_UNSPECIFIED                   NaN
# 4                FEMALE                  FST3
#
#   race_ethnicity_american_indian_or_alaska_native race_ethnicity_asian  \
# 0                                             NaN                  NaN
# 1                                             NaN                  NaN
# 2                                             NaN                  NaN
# 3                                             NaN                  NaN
# 4                                             NaN                  NaN
#
#   race_ethnicity_black_or_african_american  ...         related_category  \
# 0                                      NaN  ...                     RASH
# 1                                      NaN  ...                      NaN
# 2                                      NaN  ...  OTHER_ISSUE_DESCRIPTION
# 3                                      NaN  ...  OTHER_ISSUE_DESCRIPTION
# 4                                      NaN  ...                     RASH
#
#   condition_duration                             image_1_path  \
# 0            ONE_DAY  dataset/images/-3205742176803893704.png
# 1                NaN  dataset/images/-4762289084741430925.png
# 2  ONE_TO_FOUR_WEEKS  dataset/images/-4027806997035329030.png
# 3            ONE_DAY  dataset/images/-5332065579713135540.png
# 4            ONE_DAY  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                                NaN
# 4          CLOSE_UP                              WHITE
#
#   race_ethnicity_two_or_more_after_mitigation
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 57 columns]

# %%
print('Columns: /n', cases_df.columns)
# Out:
# Columns: /n Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type',
#        'race_ethnicity_american_indian_or_alaska_native',
#        'race_ethnicity_asian', 'race_ethnicity_black_or_african_american',
#        'race_ethnicity_hispanic_latino_or_spanish_origin',
#        'race_ethnicity_middle_eastern_or_north_african',
#        'race_ethnicity_native_hawaiian_or_pacific_islander',
#        'race_ethnicity_white', 'race_ethnicity_other_race',
#        'race_ethnicity_prefer_not_to_answer', 'textures_raised_or_bumpy',
#        'textures_flat', 'textures_rough_or_flaky', 'textures_fluid_filled',
#        'body_parts_head_or_neck', 'body_parts_arm', 'body_parts_palm',
#        'body_parts_back_of_hand', 'body_parts_torso_front',
#        'body_parts_torso_back', 'body_parts_genitalia_or_groin',
#        'body_parts_buttocks', 'body_parts_leg', 'body_parts_foot_top_or_side',
#        'body_parts_foot_sole', 'body_parts_other',
#        'condition_symptoms_bothersome_appearance',
#        'condition_symptoms_bleeding', 'condition_symptoms_increasing_size',
#        'condition_symptoms_darkening', 'condition_symptoms_itching',
#        'condition_symptoms_burning', 'condition_symptoms_pain',
#        'condition_symptoms_no_relevant_experience', 'other_symptoms_fever',
#        'other_symptoms_chills', 'other_symptoms_fatigue',
#        'other_symptoms_joint_pain', 'other_symptoms_mouth_sores',
#        'other_symptoms_shortness_of_breath',
#        'other_symptoms_no_relevant_symptoms', 'related_category',
#        'condition_duration', 'image_1_path', 'image_2_path', 'image_3_path',
#        'image_1_shot_type', 'image_2_shot_type', 'image_3_shot_type',
#        'combined_race', 'race_ethnicity_two_or_more_after_mitigation'],
#       dtype='object')

# %%
labels_df.head()
# Out:
#                case_id dermatologist_gradable_for_skin_condition_1  \
# 0 -1000600354148496558        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1 -1002039107727665188        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2 -1003358831658393077        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3 -1003826561155964328               NO_IMAGE_QUALITY_INSUFFICIENT
# 4 -1003844406100696311        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#   dermatologist_gradable_for_skin_condition_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_gradable_for_skin_condition_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#           dermatologist_skin_condition_on_label_name  \
# 0  ['Inflicted skin lesions', 'Eczema', 'Irritant...
# 1  ['Prurigo nodularis', 'Actinic Keratosis', 'SC...
# 2  ['Impetigo', 'Herpes Zoster', 'Bullous dermati...
# 3                                                 []
# 4  ['Lichen planus/lichenoid eruption', 'Follicul...
#
#   dermatologist_skin_condition_confidence  \
# 0                               [4, 4, 3]
# 1                               [4, 3, 4]
# 2                               [2, 1, 1]
# 3                                      []
# 4                               [1, 1, 1]
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3                                                 {}
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                 NO
# 4                                                YES
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_fitzpatrick_skin_type_label_1  \
# 0                                        FST2
# 1                                        FST1
# 2                                        FST4
# 3                                         NaN
# 4                                        FST1
#
#   dermatologist_fitzpatrick_skin_type_label_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_fitzpatrick_skin_type_label_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   gradable_for_monk_skin_tone_india gradable_for_monk_skin_tone_us  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                           True
# 3                              True                           True
# 4                              True                           True
#
#    monk_skin_tone_label_india  monk_skin_tone_label_us
# 0                         2.0                      1.0
# 1                         3.0                      3.0
# 2                         3.0                      4.0
# 3                         2.0                      4.0
# 4                         1.0                      1.0

# %%
labels_df.columns
# Out:
# Index(['case_id', 'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us'],
#       dtype='object')

# %%
### Starting with the cases_df

# %%
# List of body part columns
body_parts = [
    'body_parts_head_or_neck', 'body_parts_arm', 'body_parts_palm',
    'body_parts_back_of_hand', 'body_parts_torso_front', 'body_parts_torso_back',
    'body_parts_genitalia_or_groin', 'body_parts_buttocks', 'body_parts_leg',
    'body_parts_foot_top_or_side', 'body_parts_foot_sole', 'body_parts_other'
]

# Function to get all body parts with 'YES' flag
def get_body_parts(row):
    yes_parts = [part.replace('body_parts_', '') for part in body_parts if row[part] == 'YES']
    return ', '.join(yes_parts) if yes_parts else None

# Apply the function to create new 'body_part' column
cases_df['body_part'] = cases_df.apply(get_body_parts, axis=1)

# Drop the original body part columns
cases_df = cases_df.drop(columns=body_parts)

# Reorder columns
columns_order = ['case_id', 'body_part', 'image_1_path', 'image_2_path', 'image_3_path',
                 'image_1_shot_type', 'image_2_shot_type', 'image_3_shot_type', 'combined_race']
cases_df = cases_df[columns_order]

# Save the restructured CSV
cases_df.to_csv('data/cases_cleaned.csv', index=False)

# %%
cases_df = pd.read_csv('data/cases_cleaned.csv')

# %%
cases_df.head()
# Out:
#                case_id                                          body_part  \
# 0 -1000600354148496558                                   foot_top_or_side
# 1 -1002039107727665188                                                NaN
# 2 -1003358831658393077                                                arm
# 3 -1003826561155964328                                               palm
# 4 -1003844406100696311  head_or_neck, arm, back_of_hand, torso_front, ...
#
#                               image_1_path  \
# 0  dataset/images/-3205742176803893704.png
# 1  dataset/images/-4762289084741430925.png
# 2  dataset/images/-4027806997035329030.png
# 3  dataset/images/-5332065579713135540.png
# 4  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                                NaN
# 4          CLOSE_UP                              WHITE

# %%
cases_df['body_part'].unique()
# Out:
# array(['foot_top_or_side', nan, 'arm', 'palm',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_back, genitalia_or_groin',
#        'head_or_neck, arm, palm', 'torso_back', 'arm, torso_front',
#        'other', 'leg', 'torso_front, torso_back',
#        'torso_front, torso_back, other', 'back_of_hand',
#        'head_or_neck, torso_front', 'torso_front', 'head_or_neck',
#        'arm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, palm, leg, foot_sole', 'arm, leg',
#        'arm, torso_back, buttocks, leg',
#        'head_or_neck, torso_front, torso_back',
#        'head_or_neck, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'torso_back, other', 'arm, back_of_hand', 'arm, leg, foot_sole',
#        'genitalia_or_groin', 'head_or_neck, arm',
#        'head_or_neck, arm, palm, torso_front',
#        'head_or_neck, arm, back_of_hand, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, torso_front, torso_back, leg', 'arm, other',
#        'arm, torso_back, leg', 'arm, torso_front, torso_back',
#        'head_or_neck, arm, torso_front, torso_back, leg', 'buttocks',
#        'leg, foot_top_or_side', 'torso_front, leg',
#        'head_or_neck, arm, torso_back, buttocks, leg',
#        'arm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, leg, other', 'head_or_neck, arm, other',
#        'arm, torso_back, genitalia_or_groin, leg', 'leg, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'arm, back_of_hand, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, leg, foot_top_or_side',
#        'torso_front, torso_back, leg',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks',
#        'head_or_neck, arm, torso_front, genitalia_or_groin, leg',
#        'arm, back_of_hand, foot_top_or_side', 'arm, buttocks, leg',
#        'head_or_neck, arm, torso_back, leg',
#        'arm, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, back_of_hand, torso_front, torso_back, buttocks',
#        'arm, palm, torso_front, torso_back, buttocks',
#        'arm, torso_front, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, leg',
#        'head_or_neck, arm, palm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'torso_front, other', 'genitalia_or_groin, leg',
#        'arm, back_of_hand, torso_front, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, torso_back',
#        'arm, palm, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'arm, back_of_hand, torso_front, torso_back', 'buttocks, other',
#        'head_or_neck, arm, torso_front', 'leg, foot_top_or_side, other',
#        'buttocks, leg', 'head_or_neck, arm, back_of_hand, torso_front',
#        'arm, back_of_hand, buttocks, leg',
#        'arm, back_of_hand, leg, other', 'arm, foot_top_or_side',
#        'arm, palm', 'arm, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg, other',
#        'arm, palm, back_of_hand, foot_top_or_side, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back',
#        'arm, genitalia_or_groin, leg, foot_top_or_side',
#        'torso_back, buttocks, leg', 'foot_sole', 'arm, torso_back',
#        'foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, other',
#        'arm, torso_front, torso_back, leg, other',
#        'head_or_neck, arm, leg', 'head_or_neck, other',
#        'head_or_neck, torso_front, buttocks, leg',
#        'head_or_neck, arm, palm, back_of_hand, leg, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'palm, genitalia_or_groin, buttocks, leg',
#        'arm, back_of_hand, leg, foot_top_or_side, other',
#        'arm, torso_front, leg', 'arm, torso_front, buttocks, leg',
#        'head_or_neck, arm, torso_front, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand',
#        'head_or_neck, leg, foot_top_or_side, other',
#        'head_or_neck, arm, torso_front, leg, foot_top_or_side',
#        'torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, buttocks, leg',
#        'head_or_neck, torso_back, leg', 'head_or_neck, leg',
#        'arm, palm, back_of_hand, foot_top_or_side',
#        'back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, genitalia_or_groin',
#        'head_or_neck, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, torso_back, buttocks',
#        'palm, genitalia_or_groin, foot_top_or_side',
#        'arm, torso_back, leg, foot_top_or_side',
#        'head_or_neck, torso_front, torso_back, leg, foot_top_or_side, foot_sole',
#        'torso_back, buttocks',
#        'arm, back_of_hand, torso_back, buttocks, leg',
#        'genitalia_or_groin, buttocks, leg',
#        'head_or_neck, torso_back, other',
#        'palm, back_of_hand, foot_top_or_side, foot_sole',
#        'arm, palm, back_of_hand, leg, foot_top_or_side, foot_sole',
#        'torso_front, buttocks, leg', 'torso_back, leg',
#        'arm, foot_top_or_side, other',
#        'palm, back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back',
#        'back_of_hand, other', 'arm, back_of_hand, torso_back, leg',
#        'arm, torso_front, torso_back, leg, foot_top_or_side',
#        'genitalia_or_groin, leg, other',
#        'arm, back_of_hand, leg, foot_top_or_side',
#        'arm, back_of_hand, torso_front, torso_back, buttocks, leg',
#        'arm, back_of_hand, torso_front, leg, other', 'palm, foot_sole',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, other',
#        'arm, torso_back, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, foot_sole', 'head_or_neck, arm, buttocks, leg',
#        'arm, torso_front, buttocks',
#        'arm, palm, back_of_hand, torso_front, genitalia_or_groin, leg, foot_sole',
#        'arm, back_of_hand, torso_front, leg',
#        'genitalia_or_groin, buttocks',
#        'arm, back_of_hand, torso_front, leg, foot_top_or_side, other',
#        'arm, back_of_hand, torso_front, buttocks, leg, foot_top_or_side',
#        'buttocks, leg, foot_top_or_side', 'arm, back_of_hand, torso_back',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, arm, palm, back_of_hand, leg',
#        'genitalia_or_groin, foot_top_or_side, other',
#        'palm, back_of_hand', 'torso_back, leg, other',
#        'head_or_neck, arm, back_of_hand, torso_front, leg',
#        'head_or_neck, arm, palm, leg', 'back_of_hand, torso_front, leg',
#        'arm, back_of_hand, torso_front, torso_back, leg',
#        'head_or_neck, arm, torso_front, other',
#        'head_or_neck, torso_back',
#        'head_or_neck, arm, back_of_hand, torso_back',
#        'torso_front, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, genitalia_or_groin, leg, foot_top_or_side',
#        'head_or_neck, palm, back_of_hand, leg',
#        'head_or_neck, arm, torso_back, leg, foot_top_or_side',
#        'head_or_neck, torso_front, torso_back, leg, foot_top_or_side',
#        'arm, palm, back_of_hand, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'torso_front, leg, foot_sole',
#        'arm, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, palm, buttocks, leg, foot_top_or_side',
#        'back_of_hand, torso_front, buttocks',
#        'head_or_neck, genitalia_or_groin, buttocks',
#        'head_or_neck, back_of_hand, torso_front, torso_back, leg, foot_top_or_side',
#        'back_of_hand, genitalia_or_groin',
#        'head_or_neck, torso_front, torso_back, buttocks',
#        'arm, back_of_hand, torso_front',
#        'arm, torso_front, torso_back, genitalia_or_groin, leg',
#        'arm, back_of_hand, buttocks, leg, foot_top_or_side',
#        'arm, torso_front, genitalia_or_groin, leg',
#        'head_or_neck, arm, buttocks, leg, foot_top_or_side',
#        'head_or_neck, back_of_hand',
#        'head_or_neck, arm, torso_front, buttocks, leg', 'arm, leg, other',
#        'arm, back_of_hand, foot_top_or_side, other',
#        'head_or_neck, arm, torso_front, buttocks, other',
#        'arm, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg, foot_top_or_side, other',
#        'arm, torso_front, genitalia_or_groin, foot_top_or_side',
#        'arm, palm, back_of_hand, genitalia_or_groin, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_back, other',
#        'arm, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'arm, buttocks, other', 'back_of_hand, torso_back',
#        'arm, back_of_hand, genitalia_or_groin, leg, foot_top_or_side',
#        'arm, genitalia_or_groin, leg',
#        'arm, torso_front, torso_back, buttocks, leg, foot_top_or_side, other',
#        'head_or_neck, arm, torso_back, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand',
#        'head_or_neck, torso_back, buttocks, leg',
#        'head_or_neck, arm, torso_front, torso_back, leg, other',
#        'genitalia_or_groin, other',
#        'torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, back_of_hand, torso_front, other',
#        'torso_front, leg, foot_top_or_side',
#        'arm, torso_front, leg, other', 'buttocks, leg, other',
#        'arm, leg, foot_top_or_side, other', 'arm, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, other',
#        'torso_front, torso_back, leg, other',
#        'arm, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'arm, torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, torso_front, leg',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side, other',
#        'arm, palm, torso_front, torso_back, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, torso_front, torso_back, buttocks, leg, other',
#        'head_or_neck, back_of_hand, torso_front, leg',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'head_or_neck, arm, palm, leg, foot_sole',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks',
#        'arm, palm, back_of_hand, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, genitalia_or_groin, buttocks',
#        'arm, leg, foot_top_or_side', 'palm, foot_top_or_side',
#        'foot_top_or_side, other', 'arm, palm, back_of_hand',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, other',
#        'arm, back_of_hand, other',
#        'arm, genitalia_or_groin, buttocks, leg',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side, foot_sole, other',
#        'leg, foot_sole', 'arm, torso_back, other',
#        'arm, palm, foot_top_or_side', 'leg, foot_top_or_side, foot_sole',
#        'arm, buttocks', 'head_or_neck, leg, other',
#        'head_or_neck, arm, back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, buttocks, leg, other',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, buttocks', 'arm, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, palm',
#        'arm, palm, torso_front, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, other',
#        'arm, palm, torso_front',
#        'head_or_neck, arm, back_of_hand, torso_back, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side',
#        'head_or_neck, palm, back_of_hand, genitalia_or_groin, buttocks, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, leg, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, torso_back, leg, foot_top_or_side, foot_sole',
#        'arm, palm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'arm, palm, back_of_hand, buttocks, leg, foot_top_or_side',
#        'palm, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, torso_front, torso_back, leg',
#        'arm, torso_front, buttocks, other',
#        'head_or_neck, arm, back_of_hand, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_back, leg, other',
#        'arm, back_of_hand, buttocks',
#        'arm, back_of_hand, buttocks, other',
#        'head_or_neck, arm, torso_back',
#        'head_or_neck, torso_front, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'back_of_hand, torso_front',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, other',
#        'back_of_hand, genitalia_or_groin, leg, other',
#        'arm, back_of_hand, torso_front, foot_top_or_side',
#        'torso_front, torso_back, genitalia_or_groin, buttocks',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, torso_front, other', 'arm, genitalia_or_groin, buttocks',
#        'head_or_neck, arm, back_of_hand, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side',
#        'arm, torso_back, leg, other',
#        'head_or_neck, arm, palm, back_of_hand, torso_back, buttocks, leg',
#        'head_or_neck, arm, torso_front, genitalia_or_groin, buttocks, leg',
#        'palm, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, genitalia_or_groin, buttocks, other',
#        'back_of_hand, foot_sole', 'arm, genitalia_or_groin, other',
#        'arm, palm, back_of_hand, leg',
#        'arm, torso_front, torso_back, buttocks',
#        'head_or_neck, torso_front, torso_back, buttocks, leg',
#        'back_of_hand, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, other',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, leg',
#        'head_or_neck, palm, torso_back, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, palm, leg', 'back_of_hand, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, genitalia_or_groin, leg, other',
#        'head_or_neck, arm, palm, torso_front, genitalia_or_groin, buttocks, leg, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, other',
#        'arm, back_of_hand, torso_front, genitalia_or_groin, leg, foot_top_or_side',
#        'foot_sole, other', 'head_or_neck, arm, torso_back, buttocks',
#        'palm, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, foot_top_or_side',
#        'arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'palm, back_of_hand, genitalia_or_groin',
#        'head_or_neck, arm, torso_front, torso_back, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, genitalia_or_groin, leg, foot_sole',
#        'arm, palm, back_of_hand, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, buttocks',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, genitalia_or_groin, buttocks, leg',
#        'head_or_neck, palm, torso_front, genitalia_or_groin, buttocks, leg',
#        'arm, back_of_hand, genitalia_or_groin, buttocks, leg',
#        'torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, genitalia_or_groin, buttocks, leg, foot_top_or_side, other',
#        'head_or_neck, back_of_hand, leg, foot_top_or_side',
#        'arm, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, torso_back, leg, foot_top_or_side',
#        'back_of_hand, foot_top_or_side',
#        'arm, back_of_hand, torso_front, buttocks, leg',
#        'arm, genitalia_or_groin, leg, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, genitalia_or_groin',
#        'head_or_neck, arm, genitalia_or_groin',
#        'arm, palm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, torso_front, torso_back, leg, other',
#        'head_or_neck, arm, torso_front, torso_back, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, buttocks',
#        'head_or_neck, arm, back_of_hand, torso_back, leg',
#        'head_or_neck, torso_back, buttocks',
#        'arm, back_of_hand, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, torso_front, other', 'back_of_hand, leg',
#        'head_or_neck, arm, leg, foot_top_or_side',
#        'head_or_neck, arm, buttocks, leg, other',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'head_or_neck, arm, back_of_hand, torso_front, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, palm, torso_back, leg',
#        'head_or_neck, arm, palm, back_of_hand, buttocks, leg, other',
#        'head_or_neck, genitalia_or_groin, other',
#        'head_or_neck, palm, genitalia_or_groin',
#        'head_or_neck, buttocks, leg',
#        'palm, back_of_hand, leg, foot_top_or_side, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side',
#        'torso_back, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, foot_top_or_side',
#        'arm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side',
#        'palm, back_of_hand, leg', 'head_or_neck, genitalia_or_groin',
#        'arm, torso_front, torso_back, genitalia_or_groin, leg, other',
#        'arm, palm, back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, buttocks, foot_top_or_side',
#        'head_or_neck, buttocks, leg, other',
#        'palm, leg, foot_top_or_side',
#        'arm, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side',
#        'head_or_neck, arm, buttocks, leg, foot_sole, other',
#        'torso_front, leg, other', 'head_or_neck, arm, buttocks',
#        'head_or_neck, palm, torso_front, torso_back, genitalia_or_groin, buttocks, foot_top_or_side, foot_sole',
#        'arm, torso_back, buttocks, leg, other',
#        'back_of_hand, leg, foot_sole',
#        'head_or_neck, palm, torso_front, genitalia_or_groin, leg',
#        'arm, back_of_hand, torso_back, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, arm, back_of_hand, other',
#        'head_or_neck, torso_front, genitalia_or_groin',
#        'head_or_neck, back_of_hand, leg',
#        'back_of_hand, foot_top_or_side, other',
#        'head_or_neck, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'palm, back_of_hand, foot_top_or_side',
#        'palm, back_of_hand, other',
#        'arm, palm, back_of_hand, torso_front, torso_back',
#        'head_or_neck, back_of_hand, other',
#        'head_or_neck, arm, torso_back, genitalia_or_groin, leg, foot_sole',
#        'head_or_neck, arm, foot_sole'], dtype=object)

# %%
cases_df['body_part'].value_counts()
# Out:
# body_part
# leg                                                                    760
# arm                                                                    669
# other                                                                  273
# head_or_neck                                                           228
# torso_front                                                            140
#                                                                       ...
# head_or_neck, arm, genitalia_or_groin, buttocks                          1
# palm, foot_top_or_side                                                   1
# arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg      1
# head_or_neck, arm, back_of_hand, torso_front, torso_back, other          1
# head_or_neck, arm, foot_sole                                             1
# Name: count, Length: 390, dtype: int64

# %%
cases_df.body_part.unique()
# Out:
# array(['foot_top_or_side', nan, 'arm', 'palm',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_back, genitalia_or_groin',
#        'head_or_neck, arm, palm', 'torso_back', 'arm, torso_front',
#        'other', 'leg', 'torso_front, torso_back',
#        'torso_front, torso_back, other', 'back_of_hand',
#        'head_or_neck, torso_front', 'torso_front', 'head_or_neck',
#        'arm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, palm, leg, foot_sole', 'arm, leg',
#        'arm, torso_back, buttocks, leg',
#        'head_or_neck, torso_front, torso_back',
#        'head_or_neck, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'torso_back, other', 'arm, back_of_hand', 'arm, leg, foot_sole',
#        'genitalia_or_groin', 'head_or_neck, arm',
#        'head_or_neck, arm, palm, torso_front',
#        'head_or_neck, arm, back_of_hand, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, torso_front, torso_back, leg', 'arm, other',
#        'arm, torso_back, leg', 'arm, torso_front, torso_back',
#        'head_or_neck, arm, torso_front, torso_back, leg', 'buttocks',
#        'leg, foot_top_or_side', 'torso_front, leg',
#        'head_or_neck, arm, torso_back, buttocks, leg',
#        'arm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, leg, other', 'head_or_neck, arm, other',
#        'arm, torso_back, genitalia_or_groin, leg', 'leg, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'arm, back_of_hand, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, leg, foot_top_or_side',
#        'torso_front, torso_back, leg',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks',
#        'head_or_neck, arm, torso_front, genitalia_or_groin, leg',
#        'arm, back_of_hand, foot_top_or_side', 'arm, buttocks, leg',
#        'head_or_neck, arm, torso_back, leg',
#        'arm, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, back_of_hand, torso_front, torso_back, buttocks',
#        'arm, palm, torso_front, torso_back, buttocks',
#        'arm, torso_front, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, leg',
#        'head_or_neck, arm, palm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'torso_front, other', 'genitalia_or_groin, leg',
#        'arm, back_of_hand, torso_front, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, torso_back',
#        'arm, palm, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'arm, back_of_hand, torso_front, torso_back', 'buttocks, other',
#        'head_or_neck, arm, torso_front', 'leg, foot_top_or_side, other',
#        'buttocks, leg', 'head_or_neck, arm, back_of_hand, torso_front',
#        'arm, back_of_hand, buttocks, leg',
#        'arm, back_of_hand, leg, other', 'arm, foot_top_or_side',
#        'arm, palm', 'arm, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg, other',
#        'arm, palm, back_of_hand, foot_top_or_side, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back',
#        'arm, genitalia_or_groin, leg, foot_top_or_side',
#        'torso_back, buttocks, leg', 'foot_sole', 'arm, torso_back',
#        'foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, other',
#        'arm, torso_front, torso_back, leg, other',
#        'head_or_neck, arm, leg', 'head_or_neck, other',
#        'head_or_neck, torso_front, buttocks, leg',
#        'head_or_neck, arm, palm, back_of_hand, leg, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'palm, genitalia_or_groin, buttocks, leg',
#        'arm, back_of_hand, leg, foot_top_or_side, other',
#        'arm, torso_front, leg', 'arm, torso_front, buttocks, leg',
#        'head_or_neck, arm, torso_front, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand',
#        'head_or_neck, leg, foot_top_or_side, other',
#        'head_or_neck, arm, torso_front, leg, foot_top_or_side',
#        'torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, buttocks, leg',
#        'head_or_neck, torso_back, leg', 'head_or_neck, leg',
#        'arm, palm, back_of_hand, foot_top_or_side',
#        'back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, genitalia_or_groin',
#        'head_or_neck, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, torso_back, buttocks',
#        'palm, genitalia_or_groin, foot_top_or_side',
#        'arm, torso_back, leg, foot_top_or_side',
#        'head_or_neck, torso_front, torso_back, leg, foot_top_or_side, foot_sole',
#        'torso_back, buttocks',
#        'arm, back_of_hand, torso_back, buttocks, leg',
#        'genitalia_or_groin, buttocks, leg',
#        'head_or_neck, torso_back, other',
#        'palm, back_of_hand, foot_top_or_side, foot_sole',
#        'arm, palm, back_of_hand, leg, foot_top_or_side, foot_sole',
#        'torso_front, buttocks, leg', 'torso_back, leg',
#        'arm, foot_top_or_side, other',
#        'palm, back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back',
#        'back_of_hand, other', 'arm, back_of_hand, torso_back, leg',
#        'arm, torso_front, torso_back, leg, foot_top_or_side',
#        'genitalia_or_groin, leg, other',
#        'arm, back_of_hand, leg, foot_top_or_side',
#        'arm, back_of_hand, torso_front, torso_back, buttocks, leg',
#        'arm, back_of_hand, torso_front, leg, other', 'palm, foot_sole',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, other',
#        'arm, torso_back, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, foot_sole', 'head_or_neck, arm, buttocks, leg',
#        'arm, torso_front, buttocks',
#        'arm, palm, back_of_hand, torso_front, genitalia_or_groin, leg, foot_sole',
#        'arm, back_of_hand, torso_front, leg',
#        'genitalia_or_groin, buttocks',
#        'arm, back_of_hand, torso_front, leg, foot_top_or_side, other',
#        'arm, back_of_hand, torso_front, buttocks, leg, foot_top_or_side',
#        'buttocks, leg, foot_top_or_side', 'arm, back_of_hand, torso_back',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, arm, palm, back_of_hand, leg',
#        'genitalia_or_groin, foot_top_or_side, other',
#        'palm, back_of_hand', 'torso_back, leg, other',
#        'head_or_neck, arm, back_of_hand, torso_front, leg',
#        'head_or_neck, arm, palm, leg', 'back_of_hand, torso_front, leg',
#        'arm, back_of_hand, torso_front, torso_back, leg',
#        'head_or_neck, arm, torso_front, other',
#        'head_or_neck, torso_back',
#        'head_or_neck, arm, back_of_hand, torso_back',
#        'torso_front, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, genitalia_or_groin, leg, foot_top_or_side',
#        'head_or_neck, palm, back_of_hand, leg',
#        'head_or_neck, arm, torso_back, leg, foot_top_or_side',
#        'head_or_neck, torso_front, torso_back, leg, foot_top_or_side',
#        'arm, palm, back_of_hand, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'torso_front, leg, foot_sole',
#        'arm, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, palm, buttocks, leg, foot_top_or_side',
#        'back_of_hand, torso_front, buttocks',
#        'head_or_neck, genitalia_or_groin, buttocks',
#        'head_or_neck, back_of_hand, torso_front, torso_back, leg, foot_top_or_side',
#        'back_of_hand, genitalia_or_groin',
#        'head_or_neck, torso_front, torso_back, buttocks',
#        'arm, back_of_hand, torso_front',
#        'arm, torso_front, torso_back, genitalia_or_groin, leg',
#        'arm, back_of_hand, buttocks, leg, foot_top_or_side',
#        'arm, torso_front, genitalia_or_groin, leg',
#        'head_or_neck, arm, buttocks, leg, foot_top_or_side',
#        'head_or_neck, back_of_hand',
#        'head_or_neck, arm, torso_front, buttocks, leg', 'arm, leg, other',
#        'arm, back_of_hand, foot_top_or_side, other',
#        'head_or_neck, arm, torso_front, buttocks, other',
#        'arm, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, leg, foot_top_or_side, other',
#        'arm, torso_front, genitalia_or_groin, foot_top_or_side',
#        'arm, palm, back_of_hand, genitalia_or_groin, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_back, other',
#        'arm, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'arm, buttocks, other', 'back_of_hand, torso_back',
#        'arm, back_of_hand, genitalia_or_groin, leg, foot_top_or_side',
#        'arm, genitalia_or_groin, leg',
#        'arm, torso_front, torso_back, buttocks, leg, foot_top_or_side, other',
#        'head_or_neck, arm, torso_back, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand',
#        'head_or_neck, torso_back, buttocks, leg',
#        'head_or_neck, arm, torso_front, torso_back, leg, other',
#        'genitalia_or_groin, other',
#        'torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, back_of_hand, torso_front, other',
#        'torso_front, leg, foot_top_or_side',
#        'arm, torso_front, leg, other', 'buttocks, leg, other',
#        'arm, leg, foot_top_or_side, other', 'arm, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, other',
#        'torso_front, torso_back, leg, other',
#        'arm, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole, other',
#        'arm, torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, torso_front, leg',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side, other',
#        'arm, palm, torso_front, torso_back, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, torso_front, torso_back, buttocks, leg, other',
#        'head_or_neck, back_of_hand, torso_front, leg',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'head_or_neck, arm, palm, leg, foot_sole',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, buttocks',
#        'arm, palm, back_of_hand, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, genitalia_or_groin, buttocks',
#        'arm, leg, foot_top_or_side', 'palm, foot_top_or_side',
#        'foot_top_or_side, other', 'arm, palm, back_of_hand',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, other',
#        'arm, back_of_hand, other',
#        'arm, genitalia_or_groin, buttocks, leg',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side, foot_sole, other',
#        'leg, foot_sole', 'arm, torso_back, other',
#        'arm, palm, foot_top_or_side', 'leg, foot_top_or_side, foot_sole',
#        'arm, buttocks', 'head_or_neck, leg, other',
#        'head_or_neck, arm, back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, buttocks, leg, other',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, buttocks', 'arm, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, palm',
#        'arm, palm, torso_front, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks, other',
#        'arm, palm, torso_front',
#        'head_or_neck, arm, back_of_hand, torso_back, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side',
#        'head_or_neck, palm, back_of_hand, genitalia_or_groin, buttocks, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, leg, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, torso_back, leg, foot_top_or_side, foot_sole',
#        'arm, palm, back_of_hand, torso_front, genitalia_or_groin, leg',
#        'arm, palm, back_of_hand, buttocks, leg, foot_top_or_side',
#        'palm, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, torso_front, torso_back, leg',
#        'arm, torso_front, buttocks, other',
#        'head_or_neck, arm, back_of_hand, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_back, leg, other',
#        'arm, back_of_hand, buttocks',
#        'arm, back_of_hand, buttocks, other',
#        'head_or_neck, arm, torso_back',
#        'head_or_neck, torso_front, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'back_of_hand, torso_front',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, other',
#        'back_of_hand, genitalia_or_groin, leg, other',
#        'arm, back_of_hand, torso_front, foot_top_or_side',
#        'torso_front, torso_back, genitalia_or_groin, buttocks',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'arm, torso_front, other', 'arm, genitalia_or_groin, buttocks',
#        'head_or_neck, arm, back_of_hand, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side',
#        'arm, torso_back, leg, other',
#        'head_or_neck, arm, palm, back_of_hand, torso_back, buttocks, leg',
#        'head_or_neck, arm, torso_front, genitalia_or_groin, buttocks, leg',
#        'palm, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, genitalia_or_groin, buttocks, other',
#        'back_of_hand, foot_sole', 'arm, genitalia_or_groin, other',
#        'arm, palm, back_of_hand, leg',
#        'arm, torso_front, torso_back, buttocks',
#        'head_or_neck, torso_front, torso_back, buttocks, leg',
#        'back_of_hand, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, other',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, leg',
#        'head_or_neck, palm, torso_back, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, leg',
#        'head_or_neck, arm, torso_front, torso_back, buttocks',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, palm, leg', 'back_of_hand, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, genitalia_or_groin, leg, other',
#        'head_or_neck, arm, palm, torso_front, genitalia_or_groin, buttocks, leg, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side, other',
#        'arm, back_of_hand, torso_front, genitalia_or_groin, leg, foot_top_or_side',
#        'foot_sole, other', 'head_or_neck, arm, torso_back, buttocks',
#        'palm, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, foot_top_or_side',
#        'arm, palm, back_of_hand, torso_front, torso_back, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'palm, back_of_hand, genitalia_or_groin',
#        'head_or_neck, arm, torso_front, torso_back, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, genitalia_or_groin, leg, foot_sole',
#        'arm, palm, back_of_hand, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, torso_front, buttocks',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, genitalia_or_groin, buttocks, leg',
#        'head_or_neck, palm, torso_front, genitalia_or_groin, buttocks, leg',
#        'arm, back_of_hand, genitalia_or_groin, buttocks, leg',
#        'torso_front, torso_back, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, genitalia_or_groin, buttocks, leg, foot_top_or_side, other',
#        'head_or_neck, back_of_hand, leg, foot_top_or_side',
#        'arm, torso_back, genitalia_or_groin, buttocks, leg, foot_top_or_side',
#        'torso_front, torso_back, leg, foot_top_or_side',
#        'back_of_hand, foot_top_or_side',
#        'arm, back_of_hand, torso_front, buttocks, leg',
#        'arm, genitalia_or_groin, leg, foot_top_or_side, foot_sole',
#        'arm, back_of_hand, genitalia_or_groin',
#        'head_or_neck, arm, genitalia_or_groin',
#        'arm, palm, torso_front, torso_back, buttocks, leg, foot_top_or_side',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, torso_front, torso_back, leg, other',
#        'head_or_neck, arm, torso_front, torso_back, leg, foot_top_or_side',
#        'head_or_neck, arm, back_of_hand, buttocks',
#        'head_or_neck, arm, back_of_hand, torso_back, leg',
#        'head_or_neck, torso_back, buttocks',
#        'arm, back_of_hand, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, torso_front, other', 'back_of_hand, leg',
#        'head_or_neck, arm, leg, foot_top_or_side',
#        'head_or_neck, arm, buttocks, leg, other',
#        'head_or_neck, arm, torso_front, torso_back, genitalia_or_groin, buttocks, leg, other',
#        'head_or_neck, arm, back_of_hand, torso_front, genitalia_or_groin, buttocks, leg, foot_top_or_side, foot_sole',
#        'arm, palm, torso_back, leg',
#        'head_or_neck, arm, palm, back_of_hand, buttocks, leg, other',
#        'head_or_neck, genitalia_or_groin, other',
#        'head_or_neck, palm, genitalia_or_groin',
#        'head_or_neck, buttocks, leg',
#        'palm, back_of_hand, leg, foot_top_or_side, other',
#        'head_or_neck, arm, back_of_hand, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side',
#        'torso_back, genitalia_or_groin',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, foot_top_or_side',
#        'arm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side',
#        'palm, back_of_hand, leg', 'head_or_neck, genitalia_or_groin',
#        'arm, torso_front, torso_back, genitalia_or_groin, leg, other',
#        'arm, palm, back_of_hand, leg, foot_top_or_side',
#        'head_or_neck, arm, buttocks, foot_top_or_side',
#        'head_or_neck, buttocks, leg, other',
#        'palm, leg, foot_top_or_side',
#        'arm, torso_front, torso_back, genitalia_or_groin, leg, foot_top_or_side',
#        'head_or_neck, arm, buttocks, leg, foot_sole, other',
#        'torso_front, leg, other', 'head_or_neck, arm, buttocks',
#        'head_or_neck, palm, torso_front, torso_back, genitalia_or_groin, buttocks, foot_top_or_side, foot_sole',
#        'arm, torso_back, buttocks, leg, other',
#        'back_of_hand, leg, foot_sole',
#        'head_or_neck, palm, torso_front, genitalia_or_groin, leg',
#        'arm, back_of_hand, torso_back, buttocks, leg, foot_top_or_side, foot_sole',
#        'head_or_neck, arm, palm, back_of_hand, torso_front, torso_back, leg, foot_top_or_side, foot_sole, other',
#        'head_or_neck, arm, back_of_hand, other',
#        'head_or_neck, torso_front, genitalia_or_groin',
#        'head_or_neck, back_of_hand, leg',
#        'back_of_hand, foot_top_or_side, other',
#        'head_or_neck, torso_front, torso_back, genitalia_or_groin, buttocks, leg',
#        'palm, back_of_hand, foot_top_or_side',
#        'palm, back_of_hand, other',
#        'arm, palm, back_of_hand, torso_front, torso_back',
#        'head_or_neck, back_of_hand, other',
#        'head_or_neck, arm, torso_back, genitalia_or_groin, leg, foot_sole',
#        'head_or_neck, arm, foot_sole'], dtype=object)

# %%
labels_df.head()
# Out:
#                case_id dermatologist_gradable_for_skin_condition_1  \
# 0 -1000600354148496558        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1 -1002039107727665188        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2 -1003358831658393077        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3 -1003826561155964328               NO_IMAGE_QUALITY_INSUFFICIENT
# 4 -1003844406100696311        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#   dermatologist_gradable_for_skin_condition_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_gradable_for_skin_condition_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#           dermatologist_skin_condition_on_label_name  \
# 0  ['Inflicted skin lesions', 'Eczema', 'Irritant...
# 1  ['Prurigo nodularis', 'Actinic Keratosis', 'SC...
# 2  ['Impetigo', 'Herpes Zoster', 'Bullous dermati...
# 3                                                 []
# 4  ['Lichen planus/lichenoid eruption', 'Follicul...
#
#   dermatologist_skin_condition_confidence  \
# 0                               [4, 4, 3]
# 1                               [4, 3, 4]
# 2                               [2, 1, 1]
# 3                                      []
# 4                               [1, 1, 1]
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3                                                 {}
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                 NO
# 4                                                YES
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_fitzpatrick_skin_type_label_1  \
# 0                                        FST2
# 1                                        FST1
# 2                                        FST4
# 3                                         NaN
# 4                                        FST1
#
#   dermatologist_fitzpatrick_skin_type_label_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_fitzpatrick_skin_type_label_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   gradable_for_monk_skin_tone_india gradable_for_monk_skin_tone_us  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                           True
# 3                              True                           True
# 4                              True                           True
#
#    monk_skin_tone_label_india  monk_skin_tone_label_us
# 0                         2.0                      1.0
# 1                         3.0                      3.0
# 2                         3.0                      4.0
# 3                         2.0                      4.0
# 4                         1.0                      1.0

# %%
# Drop the rows with gradable_skin_condition = 'NO_IMAGE_QUALITY_INSUFFICIENT'
labels_df = labels_df[labels_df['dermatologist_gradable_for_skin_condition_1'] != 'NO_IMAGE_QUALITY_INSUFFICIENT']

# %%
import ast
import pandas as pd
import numpy as np

def process_weighted_label(label_str):
    try:
        if pd.isna(label_str) or label_str == '{}':
            return pd.Series([np.nan] * 6)

        label_dict = ast.literal_eval(label_str)
        sorted_items = sorted(label_dict.items(), key=lambda x: x[1], reverse=True)

        # Pad the list with (np.nan, np.nan) if there are fewer than 3 items
        sorted_items = sorted_items + [(np.nan, np.nan)] * (3 - len(sorted_items))

        return pd.Series([item for pair in sorted_items[:3] for item in pair])
    except:
        return pd.Series([np.nan] * 6)

# Apply the function to create new columns
new_columns = labels_df['weighted_skin_condition_label'].apply(process_weighted_label)
new_columns.columns = ['condition_1', 'confidence_1', 'condition_2', 'confidence_2', 'condition_3', 'confidence_3']

# Add the new columns to the DataFrame
labels_df = pd.concat([labels_df, new_columns], axis=1)

# Process Fitzpatrick skin type labels
def fst_to_num(fst):
    if pd.isna(fst):
        return np.nan
    try:
        return int(fst.replace('FST', ''))
    except:
        return np.nan

def avg_skin_type_to_category(avg):
    if pd.isna(avg):
        return np.nan
    elif 1 <= avg < 3:
        return 'white'
    elif 3 <= avg < 4:
        return 'fair'
    elif 4 <= avg < 6:
        return 'brown'
    elif avg == 6:
        return 'black'
    else:
        return np.nan

# Convert FST labels to numbers
for i in range(1, 4):
    col = f'dermatologist_fitzpatrick_skin_type_label_{i}'
    labels_df[f'{col}_num'] = labels_df[col].apply(fst_to_num)

# Calculate average skin type
labels_df['avg_skin_type'] = labels_df[[f'dermatologist_fitzpatrick_skin_type_label_{i}_num' for i in range(1, 4)]].mean(axis=1)

# Convert average to category
labels_df['skin_type_category'] = labels_df['avg_skin_type'].apply(avg_skin_type_to_category)

# Drop original columns if no longer needed
columns_to_drop = ['weighted_skin_condition_label', 'dermatologist_fitzpatrick_skin_type_label_1',
                   'dermatologist_fitzpatrick_skin_type_label_2', 'dermatologist_fitzpatrick_skin_type_label_3']
labels_df = labels_df.drop(columns=columns_to_drop)

# %%
labels_df.head()
# Out:
#                case_id dermatologist_gradable_for_skin_condition_1  \
# 0 -1000600354148496558        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1 -1002039107727665188        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2 -1003358831658393077        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 4 -1003844406100696311        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 5 -1005079160214352144        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#   dermatologist_gradable_for_skin_condition_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 4                                         NaN
# 5                                         NaN
#
#   dermatologist_gradable_for_skin_condition_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 4                                         NaN
# 5                                         NaN
#
#           dermatologist_skin_condition_on_label_name  \
# 0  ['Inflicted skin lesions', 'Eczema', 'Irritant...
# 1  ['Prurigo nodularis', 'Actinic Keratosis', 'SC...
# 2  ['Impetigo', 'Herpes Zoster', 'Bullous dermati...
# 4  ['Lichen planus/lichenoid eruption', 'Follicul...
# 5          ['Drug Rash', 'Viral Exanthem', 'Eczema']
#
#   dermatologist_skin_condition_confidence  \
# 0                               [4, 4, 3]
# 1                               [4, 3, 4]
# 2                               [2, 1, 1]
# 4                               [1, 1, 1]
# 5                               [2, 2, 1]
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 4                                                YES
# 5                                                YES
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   gradable_for_monk_skin_tone_india  ... confidence_1     condition_2  \
# 0                              True  ...         0.41          Eczema
# 1                              True  ...         0.41       SCC/SCCIS
# 2                              True  ...         0.55   Herpes Zoster
# 4                              True  ...         0.33    Folliculitis
# 5                              True  ...         0.41  Viral Exanthem
#
#    confidence_2                  condition_3  confidence_3  \
# 0          0.41  Irritant Contact Dermatitis          0.18
# 1          0.41            Actinic Keratosis          0.18
# 2          0.23           Bullous dermatitis          0.23
# 4          0.33       Dermatosis due to flea          0.33
# 5          0.41                       Eczema          0.18
#
#   dermatologist_fitzpatrick_skin_type_label_1_num  \
# 0                                             2.0
# 1                                             1.0
# 2                                             4.0
# 4                                             1.0
# 5                                             3.0
#
#    dermatologist_fitzpatrick_skin_type_label_2_num  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 4                                              NaN
# 5                                              NaN
#
#   dermatologist_fitzpatrick_skin_type_label_3_num  avg_skin_type  \
# 0                                             NaN            2.0
# 1                                             NaN            1.0
# 2                                             NaN            4.0
# 4                                             NaN            1.0
# 5                                             NaN            3.0
#
#    skin_type_category
# 0               white
# 1               white
# 2               brown
# 4               white
# 5                fair
#
# [5 rows x 24 columns]

# %%
labels_df.to_csv('data/labels_cleaned.csv', index=False)

# %%
labels_df.columns
# Out:
# Index(['case_id', 'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us', 'condition_1',
#        'confidence_1', 'condition_2', 'confidence_2', 'condition_3',
#        'confidence_3', 'dermatologist_fitzpatrick_skin_type_label_1_num',
#        'dermatologist_fitzpatrick_skin_type_label_2_num',
#        'dermatologist_fitzpatrick_skin_type_label_3_num', 'avg_skin_type',
#        'skin_type_category'],
#       dtype='object')

# %%
labels_df = labels_df.drop(columns=['dermatologist_gradable_for_skin_condition_1', 'dermatologist_gradable_for_skin_condition_2', 'dermatologist_gradable_for_skin_condition_3', 'dermatologist_skin_condition_on_label_name', 'dermatologist_skin_condition_confidence', 'dermatologist_gradable_for_fitzpatrick_skin_type_1', 'dermatologist_gradable_for_fitzpatrick_skin_type_2', 'dermatologist_gradable_for_fitzpatrick_skin_type_3','gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us', 'monk_skin_tone_label_india', 'monk_skin_tone_label_us', 'dermatologist_fitzpatrick_skin_type_label_1_num', 'dermatologist_fitzpatrick_skin_type_label_2_num', 'dermatologist_fitzpatrick_skin_type_label_3_num'])

# %%
labels_df.to_csv('data/labels_cleaned.csv', index=False)

# %%
clean_label_df = pd.read_csv('data/labels_cleaned.csv')

# %%
def clean_conditions(row):
    if row['confidence_2'] != row['confidence_1'] and row['confidence_2'] < row['confidence_1']:
        row['condition_2'] = np.nan
        row['confidence_2'] = np.nan

    if row['confidence_3'] != row['confidence_1'] and row['confidence_3'] < row['confidence_1']:
        row['condition_3'] = np.nan
        row['confidence_3'] = np.nan

    return row

# Apply the function to each row
clean_label_df = clean_label_df.apply(clean_conditions, axis=1)

# Remove rows where all conditions are NaN
clean_label_df = clean_label_df.dropna(subset=['condition_1', 'condition_2', 'condition_3'], how='all')

# %%
clean_label_df
# Out:
#                   case_id                       condition_1  confidence_1  \
# 0    -1000600354148496558            Inflicted skin lesions          0.41
# 1    -1002039107727665188                 Prurigo nodularis          0.41
# 2    -1003358831658393077                          Impetigo          0.55
# 3    -1003844406100696311  Lichen planus/lichenoid eruption          0.33
# 4    -1005079160214352144                         Drug Rash          0.41
# ...                   ...                               ...           ...
# 3103   966663640331506400                              Acne          0.33
# 3104   973759811984683137       Allergic Contact Dermatitis          0.67
# 3105   983265958160210646                          Impetigo          0.50
# 3106   995820220956352730           Erythema gyratum repens          0.33
# 3107   998890198757718998                      Folliculitis          1.00
#
#                 condition_2  confidence_2  \
# 0                    Eczema          0.41
# 1                 SCC/SCCIS          0.41
# 2                       NaN           NaN
# 3              Folliculitis          0.33
# 4            Viral Exanthem          0.41
# ...                     ...           ...
# 3103  Molluscum Contagiosum          0.33
# 3104                    NaN           NaN
# 3105           Foreign body          0.50
# 3106  Seborrheic Dermatitis          0.33
# 3107                    NaN           NaN
#
#                                        condition_3  confidence_3  \
# 0                                              NaN           NaN
# 1                                              NaN           NaN
# 2                                              NaN           NaN
# 3                           Dermatosis due to flea          0.33
# 4                                              NaN           NaN
# ...                                            ...           ...
# 3103                                Herpes Simplex          0.33
# 3104                                           NaN           NaN
# 3105                                           NaN           NaN
# 3106  Erythema marginatum in acute rheumatic fever          0.33
# 3107                                           NaN           NaN
#
#       avg_skin_type skin_type_category
# 0          2.000000              white
# 1          1.000000              white
# 2          4.000000              brown
# 3          1.000000              white
# 4          3.000000               fair
# ...             ...                ...
# 3103       2.000000              white
# 3104       2.333333              white
# 3105       5.000000              brown
# 3106       4.000000              brown
# 3107            NaN                NaN
#
# [3005 rows x 9 columns]

# %%
clean_label_df.condition_1.unique().count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 clean_label_df.condition_1.unique().count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
condition_summary = pd.DataFrame({
    'count': clean_label_df['condition_1'].value_counts(),
    'percentage': clean_label_df['condition_1'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(10))
# Out:
#                              count  percentage
# condition_1
# Eczema                         479       15.94
# Allergic Contact Dermatitis    266        8.85
# Urticaria                      208        6.92
# Insect Bite                    183        6.09
# Folliculitis                   140        4.66
# Psoriasis                      107        3.56
# Tinea                           92        3.06
# Impetigo                        68        2.26
# Herpes Zoster                   67        2.23
# Pigmented purpuric eruption     61        2.03

# %%
condition_summary = pd.DataFrame({
    'count': clean_label_df['condition_2'].value_counts(),
    'percentage': clean_label_df['condition_2'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(10))
# Out:
#                              count  percentage
# condition_2
# Allergic Contact Dermatitis    163       17.91
# Eczema                         118       12.97
# Insect Bite                     63        6.92
# Irritant Contact Dermatitis     45        4.95
# Psoriasis                       31        3.41
# Folliculitis                    25        2.75
# Herpes Simplex                  20        2.20
# Leukocytoclastic Vasculitis     17        1.87
# Stasis Dermatitis               16        1.76
# Herpes Zoster                   16        1.76

# %%
condition_summary = pd.DataFrame({
    'count': clean_label_df['condition_3'].value_counts(),
    'percentage': clean_label_df['condition_3'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(10))
# Out:
#                              count  percentage
# condition_3
# Allergic Contact Dermatitis     86       22.75
# Eczema                          42       11.11
# Irritant Contact Dermatitis     31        8.20
# Herpes Simplex                  21        5.56
# Leukocytoclastic Vasculitis     16        4.23
# Hypersensitivity                16        4.23
# Insect Bite                     15        3.97
# Lichen Simplex Chronicus         9        2.38
# Psoriasis                        8        2.12
# Seborrheic Dermatitis            6        1.59

# %%
# Create a boolean mask where no two confidence values are equal
mask = ~(
        (clean_label_df['confidence_1'] == clean_label_df['confidence_2']) |
        (clean_label_df['confidence_1'] == clean_label_df['confidence_3']) |
        (clean_label_df['confidence_2'] == clean_label_df['confidence_3'])
)

# Apply the mask to keep only rows where no two confidences are equal
clean_label_df = clean_label_df[mask]

# Reset the index
clean_label_df = clean_label_df.reset_index(drop=True)

# %%
clean_label_df.drop(columns=['condition_2', 'condition_3','confidence_2', 'confidence_3'])
# Out:
#                   case_id                  condition_1  confidence_1  \
# 0    -1003358831658393077                     Impetigo          0.55
# 1    -1013831220015814987         Basal Cell Carcinoma          0.55
# 2     -101827005996397499                       Eczema          0.67
# 3    -1022162013984621110                      Purpura          1.00
# 4    -1031911667791094656                       Eczema          0.55
# ...                   ...                          ...           ...
# 2090   935346003160692168                    Psoriasis          1.00
# 2091    95226461955873076                       Eczema          0.68
# 2092   963694477603925530                  Insect Bite          0.55
# 2093   973759811984683137  Allergic Contact Dermatitis          0.67
# 2094   998890198757718998                 Folliculitis          1.00
#
#       avg_skin_type skin_type_category
# 0          4.000000              brown
# 1          3.000000               fair
# 2          3.666667               fair
# 3          4.000000              brown
# 4          2.000000              white
# ...             ...                ...
# 2090       3.000000               fair
# 2091       2.000000              white
# 2092       2.000000              white
# 2093       2.333333              white
# 2094            NaN                NaN
#
# [2095 rows x 5 columns]

# %%
condition_summary = pd.DataFrame({
    'count': clean_label_df['condition_1'].value_counts(),
    'percentage': clean_label_df['condition_1'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(10))
# Out:
#                              count  percentage
# condition_1
# Eczema                         360       17.18
# Allergic Contact Dermatitis    220       10.50
# Urticaria                      170        8.11
# Insect Bite                    133        6.35
# Folliculitis                    91        4.34
# Psoriasis                       65        3.10
# Tinea                           60        2.86
# Herpes Simplex                  54        2.58
# Herpes Zoster                   45        2.15
# Acne                            45        2.15

# %%
clean_label_df_filtered = clean_label_df[clean_label_df['confidence_1'] > 0.5]

# %%
condition_summary = pd.DataFrame({
    'count': clean_label_df_filtered['condition_1'].value_counts(),
    'percentage': clean_label_df_filtered['condition_1'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(10))
# Out:
#                              count  percentage
# condition_1
# Eczema                         312       16.67
# Allergic Contact Dermatitis    192       10.26
# Urticaria                      160        8.55
# Insect Bite                    119        6.36
# Folliculitis                    84        4.49
# Psoriasis                       55        2.94
# Tinea                           55        2.94
# Herpes Simplex                  51        2.72
# Herpes Zoster                   45        2.40
# Acne                            42        2.24

# %%
clean_label_df_filtered = clean_label_df_filtered.drop(columns=['condition_2', 'condition_3','confidence_2', 'confidence_3'])

# %%
clean_label_df_filtered.head()
# Out:
#                case_id           condition_1  confidence_1  avg_skin_type  \
# 0 -1003358831658393077              Impetigo          0.55       4.000000
# 1 -1013831220015814987  Basal Cell Carcinoma          0.55       3.000000
# 2  -101827005996397499                Eczema          0.67       3.666667
# 3 -1022162013984621110               Purpura          1.00       4.000000
# 4 -1031911667791094656                Eczema          0.55       2.000000
#
#   skin_type_category
# 0              brown
# 1               fair
# 2               fair
# 3              brown
# 4              white

# %%
clean_label_df_filtered.to_csv('data/labels_cleaned_filtered.csv', index=False)

# %%
unique_conditions = clean_label_df_filtered['condition_1'].unique()
unique_conditions
# Out:
# array(['Impetigo', 'Basal Cell Carcinoma', 'Eczema', 'Purpura',
#        'Urticaria', 'Tinea Versicolor', 'Hyperpigmentation',
#        'Infected eczema', 'Pityriasis rosea', 'Onychodystrophy',
#        'Inflicted skin lesions', 'Chronic dermatitis, NOS', 'Tinea',
#        'Psoriasis', 'Herpes Simplex', 'Pigmented purpuric eruption',
#        'Granuloma annulare', 'Herpes Zoster',
#        'Confluent and reticulate papillomatosis', 'Molluscum Contagiosum',
#        'Allergic Contact Dermatitis', 'Acne', 'Abscess', 'Rosacea',
#        'Acute and chronic dermatitis', 'wound/abrasion',
#        'Irritant Contact Dermatitis', 'O/E - ecchymoses present',
#        'Verruca vulgaris', 'Lichen nitidus',
#        'Lichen planus/lichenoid eruption', 'Insect Bite', 'Onychomycosis',
#        'Animal bite - wound', 'Acute dermatitis, NOS',
#        'Post-Inflammatory hypopigmentation', 'Ecthyma',
#        'Hemosiderin pigmentation of skin due to venous insufficiency',
#        'Dermatofibroma', 'Seborrheic Dermatitis',
#        'Perforating dermatosis', 'Lichen Simplex Chronicus', 'Blister',
#        'Folliculitis', 'Hypersensitivity', 'Erythema multiforme',
#        'Post-Inflammatory hyperpigmentation', 'SCC/SCCIS',
#        'Keratosis pilaris', 'Cutaneous metastasis',
#        'O/E - petechiae present', 'Perioral Dermatitis',
#        'Stasis Dermatitis', 'Geographic tongue',
#        'CD - Contact dermatitis', 'Remove from labeling tool',
#        'Photodermatitis', 'Condyloma acuminatum', "Grover's disease",
#        'Foot ulcer', 'Superficial wound of body region', 'Cyst',
#        'Lichen striatus', 'Abrasion, scrape, or scab',
#        'Candida intertrigo', 'Drug Rash', 'Leukocytoclastic Vasculitis',
#        'Cutaneous lupus', 'Erythema ab igne', 'Viral Exanthem',
#        'Skin ulcer', 'Prurigo nodularis', 'Koebner phenomenon',
#        'Acute-on-chronic dyshidrotic eczema of hands',
#        'Idiopathic guttate hypomelanosis', 'Lymphangioma', 'Cellulitis',
#        'Venous Stasis Ulcer', 'Erythema migrans', 'Actinic Keratosis',
#        'varicose vein', 'Acanthosis nigricans',
#        'Erythema dyschromicum perstans', 'Morbilliform eruption',
#        'Cheilitis', 'Erythema nodosum', 'Keratolysis exfoliativa',
#        'Localized skin infection', 'Eruptive xanthoma',
#        'Lichenified eczematous dermatitis', 'O/E - petechiae on skin',
#        'Acne keloidalis', 'Intertrigo', 'Morphea/Scleroderma',
#        'Erythema gyratum repens', 'Scar Condition', 'Scabies',
#        'Skin infection', 'Chilblain', 'Arsenical keratosis',
#        'Annular erythema', 'Bullous Pemphigoid', 'Hemangioma',
#        'Foreign body reaction of the skin', 'Lichenified eczema',
#        'SK/ISK', 'Knuckle pads',
#        'TMEP - telangiectasia macularis eruptiva perstans',
#        'Hidradenitis', 'Miliaria', 'AKV - Acrokeratosis verruciformis',
#        'Hand foot and mouth disease', 'Pityriasis lichenoides',
#        'Traumatic blister', 'Xerosis', 'HK - Hyperkeratosis',
#        'Livedo reticularis', 'Varicose veins of lower extremity',
#        'Sunburn', 'Cutaneous larva migrans', 'Milia', 'Paronychia',
#        'Burn of skin', 'Contact dermatitis, NOS',
#        'B-Cell Cutaneous Lymphoma', 'Vasculitis of the skin',
#        'Acute constitutional eczema', 'Cutaneous sarcoidosis',
#        'O/E - vesicles present', 'Acne urticata', 'Elephantiasis nostras',
#        'Cutaneous T Cell Lymphoma',
#        'Hemosiderin pigmentation of lower limb due to varicose veins of lower limb',
#        'On examination - follicular pustules', 'Leukonychia',
#        'Poikiloderma', 'Ichthyosis', 'Deep fungal infection',
#        'Agminate folliculitis', 'O/E - pustules', 'Amyloidosis of skin',
#        'Melasma', 'Ecthyma gangrenosum', 'Melanocytic Nevus', 'Vitiligo',
#        'Lichen spinulosus', 'Majocchi granuloma', 'Inverse psoriasis',
#        'Epidermal nevus', 'Pincer nail deformity',
#        'Skin lesion in drug addict', 'unilateral laterothoracic exanthem',
#        'Prurigo', 'Jessner lymphocytic infiltrate', 'Rheumatoid nodule',
#        'Poisoning by nematocyst', 'Local infection of wound', 'Syphilis',
#        'Porokeratosis', 'Contact dermatitis caused by Rhus diversiloba',
#        'Melanin pigmentation due to exogenous substance',
#        'Actinic granuloma', 'Traumatic ulcer', 'Lichenoid myxedema',
#        'Pyogenic granuloma', 'Chicken pox exanthem'], dtype=object)

# %%
condition_summary[condition_summary['count']>30].plot(kind='bar', figsize=(12, 6), color='skyblue')
# Out:
# <Axes: xlabel='condition_1'>

# %%
condition_summary
# Out:
#                                     count  percentage
# condition_1
# Eczema                                312       16.67
# Allergic Contact Dermatitis           192       10.26
# Urticaria                             160        8.55
# Insect Bite                           119        6.36
# Folliculitis                           84        4.49
# ...                                   ...         ...
# unilateral laterothoracic exanthem      1        0.05
# Skin lesion in drug addict              1        0.05
# Vitiligo                                1        0.05
# Pincer nail deformity                   1        0.05
# Chicken pox exanthem                    1        0.05
#
# [166 rows x 2 columns]

# %%
unique_conditions.contains("Dermatitis")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 unique_conditions.contains("Dermatitis")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'contains'

# %%
condition_summary.to_csv('data/condition_summary.csv')

# %%
#### Data Cleaning is done

# %%
## Loading the cleaned data

# %%
import pandas as pd

# %%
df_case = pd.read_csv('data/cases_cleaned.csv')

# %%
df_case.head()
# Out:
#                case_id                                          body_part  \
# 0 -1000600354148496558                                   foot_top_or_side
# 1 -1002039107727665188                                                NaN
# 2 -1003358831658393077                                                arm
# 3 -1003826561155964328                                               palm
# 4 -1003844406100696311  head_or_neck, arm, back_of_hand, torso_front, ...
#
#                               image_1_path  \
# 0  dataset/images/-3205742176803893704.png
# 1  dataset/images/-4762289084741430925.png
# 2  dataset/images/-4027806997035329030.png
# 3  dataset/images/-5332065579713135540.png
# 4  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                                NaN
# 4          CLOSE_UP                              WHITE

# %%
df_label = pd.read_csv('data/labels_cleaned_filtered.csv')

# %%
df_label.head()
# Out:
#                case_id           condition_1  confidence_1  avg_skin_type  \
# 0 -1003358831658393077              Impetigo          0.55       4.000000
# 1 -1013831220015814987  Basal Cell Carcinoma          0.55       3.000000
# 2  -101827005996397499                Eczema          0.67       3.666667
# 3 -1022162013984621110               Purpura          1.00       4.000000
# 4 -1031911667791094656                Eczema          0.55       2.000000
#
#   skin_type_category
# 0              brown
# 1               fair
# 2               fair
# 3              brown
# 4              white

# %%
df_case.head()
# Out:
#                case_id                                          body_part  \
# 0 -1000600354148496558                                   foot_top_or_side
# 1 -1002039107727665188                                                NaN
# 2 -1003358831658393077                                                arm
# 3 -1003826561155964328                                               palm
# 4 -1003844406100696311  head_or_neck, arm, back_of_hand, torso_front, ...
#
#                               image_1_path  \
# 0  dataset/images/-3205742176803893704.png
# 1  dataset/images/-4762289084741430925.png
# 2  dataset/images/-4027806997035329030.png
# 3  dataset/images/-5332065579713135540.png
# 4  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                                NaN
# 4          CLOSE_UP                              WHITE

# %%
df_label.head()
# Out:
#                case_id           condition_1  confidence_1  avg_skin_type  \
# 0 -1003358831658393077              Impetigo          0.55       4.000000
# 1 -1013831220015814987  Basal Cell Carcinoma          0.55       3.000000
# 2  -101827005996397499                Eczema          0.67       3.666667
# 3 -1022162013984621110               Purpura          1.00       4.000000
# 4 -1031911667791094656                Eczema          0.55       2.000000
#
#   skin_type_category
# 0              brown
# 1               fair
# 2               fair
# 3              brown
# 4              white

# %%
df_case.dtypes
# Out:
# case_id               int64
# body_part            object
# image_1_path         object
# image_2_path         object
# image_3_path         object
# image_1_shot_type    object
# image_2_shot_type    object
# image_3_shot_type    object
# combined_race        object
# dtype: object

# %%
df_label.dtypes
# Out:
# case_id                 int64
# condition_1            object
# confidence_1          float64
# avg_skin_type         float64
# skin_type_category     object
# dtype: object

# %%
df_case_label = df_case.join(df_label.set_index('case_id'), on='case_id')

# %%
df_case_label.head()
# Out:
#                case_id                                          body_part  \
# 0 -1000600354148496558                                   foot_top_or_side
# 1 -1002039107727665188                                                NaN
# 2 -1003358831658393077                                                arm
# 3 -1003826561155964328                                               palm
# 4 -1003844406100696311  head_or_neck, arm, back_of_hand, torso_front, ...
#
#                               image_1_path  \
# 0  dataset/images/-3205742176803893704.png
# 1  dataset/images/-4762289084741430925.png
# 2  dataset/images/-4027806997035329030.png
# 3  dataset/images/-5332065579713135540.png
# 4  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race condition_1  \
# 0               NaN                                NaN         NaN
# 1               NaN                                NaN         NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN    Impetigo
# 3          CLOSE_UP                                NaN         NaN
# 4          CLOSE_UP                              WHITE         NaN
#
#    confidence_1  avg_skin_type skin_type_category
# 0           NaN            NaN                NaN
# 1           NaN            NaN                NaN
# 2          0.55            4.0              brown
# 3           NaN            NaN                NaN
# 4           NaN            NaN                NaN

# %%
df_case_label = df_case_label[df_case_label['condition_1'].notna()]

# %%
df_case_label.head()
# Out:
#                 case_id   body_part                             image_1_path  \
# 2  -1003358831658393077         arm  dataset/images/-4027806997035329030.png
# 7  -1013831220015814987  torso_back   dataset/images/-220649468572111832.png
# 8   -101827005996397499         arm   dataset/images/-217828380359571871.png
# 9  -1022162013984621110         NaN   dataset/images/8406712750126834903.png
# 10 -1031911667791094656         NaN  dataset/images/-3712452163219577722.png
#
#                                image_2_path  \
# 2                                       NaN
# 7                                       NaN
# 8   dataset/images/-4055728304670056584.png
# 9                                       NaN
# 10   dataset/images/-983426416985154601.png
#
#                               image_3_path image_1_shot_type  \
# 2                                      NaN          CLOSE_UP
# 7                                      NaN          CLOSE_UP
# 8                                      NaN          CLOSE_UP
# 9                                      NaN          CLOSE_UP
# 10  dataset/images/8538075517728087299.png       AT_DISTANCE
#
#    image_2_shot_type image_3_shot_type                      combined_race  \
# 2                NaN               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 7                NaN               NaN                              WHITE
# 8        AT_AN_ANGLE               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 9                NaN               NaN                                NaN
# 10       AT_AN_ANGLE          CLOSE_UP                                NaN
#
#              condition_1  confidence_1  avg_skin_type skin_type_category
# 2               Impetigo          0.55       4.000000              brown
# 7   Basal Cell Carcinoma          0.55       3.000000               fair
# 8                 Eczema          0.67       3.666667               fair
# 9                Purpura          1.00       4.000000              brown
# 10                Eczema          0.55       2.000000              white

# %%
len(df_case_label)
# Out:
# 1872

# %%
df_case_label.to_csv('data/case_label.csv', index=False)

# %%
df_case_label.dtypes
# Out:
# case_id                 int64
# body_part              object
# image_1_path           object
# image_2_path           object
# image_3_path           object
# image_1_shot_type      object
# image_2_shot_type      object
# image_3_shot_type      object
# combined_race          object
# condition_1            object
# confidence_1          float64
# avg_skin_type         float64
# skin_type_category     object
# dtype: object

# %%
df_case_label = df_case_label[~df_case_label['body_part'].astype(str).str.lower().str.contains('groin', na=False)]

# %%
print(df_case_label.dtypes)
# Out:
# case_id                 int64
# body_part              object
# image_1_path           object
# image_2_path           object
# image_3_path           object
# image_1_shot_type      object
# image_2_shot_type      object
# image_3_shot_type      object
# combined_race          object
# condition_1            object
# confidence_1          float64
# avg_skin_type         float64
# skin_type_category     object
# dtype: object

# %%
df_case_label = df_case_label.astype({
    'case_id': 'int64', 
    'body_part': 'object',
    'image_1_path': 'string',
    'image_2_path': 'string',
    'image_3_path': 'string',
    'image_1_shot_type': 'string',
    'image_2_shot_type': 'string',
    'image_3_shot_type': 'string',
    'combined_race': 'string',
    'condition_1': 'string',
    'confidence_1': 'float32',  
    'avg_skin_type': 'float32',
    'skin_type_category': 'string'
})

# %%
df_case_label
# Out:
#                   case_id    body_part  \
# 2    -1003358831658393077          arm
# 7    -1013831220015814987   torso_back
# 8     -101827005996397499          arm
# 9    -1022162013984621110          NaN
# 10   -1031911667791094656          NaN
# ...                   ...          ...
# 5018   935346003160692168          NaN
# 5021    95226461955873076        other
# 5025   963694477603925530          arm
# 5028   973759811984683137          arm
# 5032   998890198757718998  torso_front
#
#                                  image_1_path  \
# 2     dataset/images/-4027806997035329030.png
# 7      dataset/images/-220649468572111832.png
# 8      dataset/images/-217828380359571871.png
# 9      dataset/images/8406712750126834903.png
# 10    dataset/images/-3712452163219577722.png
# ...                                       ...
# 5018  dataset/images/-8779903138873713227.png
# 5021  dataset/images/-4308398826912860778.png
# 5025  dataset/images/-1642667040160094612.png
# 5028     dataset/images/32575980331712012.png
# 5032   dataset/images/8953015289412905592.png
#
#                                  image_2_path  \
# 2                                        <NA>
# 7                                        <NA>
# 8     dataset/images/-4055728304670056584.png
# 9                                        <NA>
# 10     dataset/images/-983426416985154601.png
# ...                                       ...
# 5018                                     <NA>
# 5021    dataset/images/509954653626260883.png
# 5025                                     <NA>
# 5028   dataset/images/5167477372002548597.png
# 5032                                     <NA>
#
#                                 image_3_path image_1_shot_type  \
# 2                                       <NA>          CLOSE_UP
# 7                                       <NA>          CLOSE_UP
# 8                                       <NA>          CLOSE_UP
# 9                                       <NA>          CLOSE_UP
# 10    dataset/images/8538075517728087299.png       AT_DISTANCE
# ...                                      ...               ...
# 5018                                    <NA>          CLOSE_UP
# 5021   dataset/images/724924647087331057.png       AT_DISTANCE
# 5025                                    <NA>          CLOSE_UP
# 5028                                    <NA>          CLOSE_UP
# 5032                                    <NA>          CLOSE_UP
#
#      image_2_shot_type image_3_shot_type                      combined_race  \
# 2                 <NA>              <NA>  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 7                 <NA>              <NA>                              WHITE
# 8          AT_AN_ANGLE              <NA>  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 9                 <NA>              <NA>                               <NA>
# 10         AT_AN_ANGLE          CLOSE_UP                               <NA>
# ...                ...               ...                                ...
# 5018              <NA>              <NA>                               <NA>
# 5021       AT_AN_ANGLE          CLOSE_UP                              WHITE
# 5025              <NA>              <NA>                              WHITE
# 5028       AT_AN_ANGLE              <NA>       TWO_OR_MORE_AFTER_MITIGATION
# 5032              <NA>              <NA>   AMERICAN_INDIAN_OR_ALASKA_NATIVE
#
#                       condition_1  confidence_1  avg_skin_type  \
# 2                        Impetigo          0.55       4.000000
# 7            Basal Cell Carcinoma          0.55       3.000000
# 8                          Eczema          0.67       3.666667
# 9                         Purpura          1.00       4.000000
# 10                         Eczema          0.55       2.000000
# ...                           ...           ...            ...
# 5018                    Psoriasis          1.00       3.000000
# 5021                       Eczema          0.68       2.000000
# 5025                  Insect Bite          0.55       2.000000
# 5028  Allergic Contact Dermatitis          0.67       2.333333
# 5032                 Folliculitis          1.00            NaN
#
#      skin_type_category
# 2                 brown
# 7                  fair
# 8                  fair
# 9                 brown
# 10                white
# ...                 ...
# 5018               fair
# 5021              white
# 5025              white
# 5028              white
# 5032               <NA>
#
# [1799 rows x 13 columns]

# %%
df_case_label[df_case_label['confidence_1'] >= 0.8].count()['case_id']
# Out:
# 655

# %%
df_case_label = df_case_label[df_case_label['confidence_1'] >= 0.8]

# %%
df_case_label.to_csv('data/case_label_filtered.csv', index=False)

# %%
df_case_label
# Out:
#                   case_id    body_part  \
# 9    -1022162013984621110          NaN
# 11   -1033431645373513522          NaN
# 23   -1073544188024944010          NaN
# 25   -1079717215777778516          NaN
# 35   -1120481478267460560          leg
# ...                   ...          ...
# 4977  9094416934450217084          NaN
# 4984  9105346707210308949          arm
# 5016   930124461134778983          leg
# 5018   935346003160692168          NaN
# 5032   998890198757718998  torso_front
#
#                                  image_1_path  \
# 9      dataset/images/8406712750126834903.png
# 11    dataset/images/-1677898261371801194.png
# 23    dataset/images/-1542787778564695920.png
# 25    dataset/images/-3060870142909393201.png
# 35    dataset/images/-3933475004882152757.png
# ...                                       ...
# 4977  dataset/images/-4639546377033199002.png
# 4984  dataset/images/-3238683302029267521.png
# 5016  dataset/images/-2787315420624607465.png
# 5018  dataset/images/-8779903138873713227.png
# 5032   dataset/images/8953015289412905592.png
#
#                                  image_2_path  \
# 9                                        <NA>
# 11     dataset/images/2587768503558995392.png
# 23    dataset/images/-3253987854671575512.png
# 25                                       <NA>
# 35    dataset/images/-6233451743223829948.png
# ...                                       ...
# 4977                                     <NA>
# 4984  dataset/images/-7141594063372177636.png
# 5016  dataset/images/-8048467112742368195.png
# 5018                                     <NA>
# 5032                                     <NA>
#
#                                  image_3_path image_1_shot_type  \
# 9                                        <NA>          CLOSE_UP
# 11     dataset/images/5836170508263925618.png          CLOSE_UP
# 23      dataset/images/108462233489916244.png          CLOSE_UP
# 25                                       <NA>          CLOSE_UP
# 35     dataset/images/-764324206369620251.png          CLOSE_UP
# ...                                       ...               ...
# 4977                                     <NA>          CLOSE_UP
# 4984  dataset/images/-8970062608215251005.png       AT_AN_ANGLE
# 5016   dataset/images/6371452221179710784.png          CLOSE_UP
# 5018                                     <NA>          CLOSE_UP
# 5032                                     <NA>          CLOSE_UP
#
#      image_2_shot_type image_3_shot_type                     combined_race  \
# 9                 <NA>              <NA>                              <NA>
# 11         AT_DISTANCE       AT_AN_ANGLE                              <NA>
# 23         AT_DISTANCE       AT_AN_ANGLE                              <NA>
# 25                <NA>              <NA>                              <NA>
# 35         AT_DISTANCE       AT_AN_ANGLE                              <NA>
# ...                ...               ...                               ...
# 4977              <NA>              <NA>                              <NA>
# 4984          CLOSE_UP       AT_DISTANCE                              <NA>
# 5016       AT_AN_ANGLE       AT_DISTANCE                             WHITE
# 5018              <NA>              <NA>                              <NA>
# 5032              <NA>              <NA>  AMERICAN_INDIAN_OR_ALASKA_NATIVE
#
#                condition_1  confidence_1  avg_skin_type skin_type_category
# 9                  Purpura           1.0            4.0              brown
# 11               Urticaria           1.0            3.0               fair
# 23               Urticaria           1.0            NaN               <NA>
# 25                  Eczema           1.0            3.0               fair
# 35                  Eczema           1.0            3.0               fair
# ...                    ...           ...            ...                ...
# 4977  Chicken pox exanthem           1.0            2.0              white
# 4984                Eczema           1.0            2.0              white
# 5016     Stasis Dermatitis           1.0            3.0               fair
# 5018             Psoriasis           1.0            3.0               fair
# 5032          Folliculitis           1.0            NaN               <NA>
#
# [655 rows x 13 columns]

# %%
condition_summary = pd.DataFrame({
    'count': clean_label_df_filtered['condition_1'].value_counts(),
    'percentage': clean_label_df_filtered['condition_1'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(50))
# Out:
#                              count  percentage
# condition_1
# Eczema                         312       16.67
# Allergic Contact Dermatitis    192       10.26
# Urticaria                      160        8.55
# Insect Bite                    119        6.36
# Folliculitis                    84        4.49
# Psoriasis                       55        2.94
# Tinea                           55        2.94
# Herpes Simplex                  51        2.72
# Herpes Zoster                   45        2.40
# Acne                            42        2.24

# %%
condition_summary.to_csv('data/condition_summary_final.csv')

# %%
df_case_label
# Out:
#                   case_id    body_part  \
# 9    -1022162013984621110          NaN
# 11   -1033431645373513522          NaN
# 23   -1073544188024944010          NaN
# 25   -1079717215777778516          NaN
# 35   -1120481478267460560          leg
# ...                   ...          ...
# 4977  9094416934450217084          NaN
# 4984  9105346707210308949          arm
# 5016   930124461134778983          leg
# 5018   935346003160692168          NaN
# 5032   998890198757718998  torso_front
#
#                                  image_1_path  \
# 9      dataset/images/8406712750126834903.png
# 11    dataset/images/-1677898261371801194.png
# 23    dataset/images/-1542787778564695920.png
# 25    dataset/images/-3060870142909393201.png
# 35    dataset/images/-3933475004882152757.png
# ...                                       ...
# 4977  dataset/images/-4639546377033199002.png
# 4984  dataset/images/-3238683302029267521.png
# 5016  dataset/images/-2787315420624607465.png
# 5018  dataset/images/-8779903138873713227.png
# 5032   dataset/images/8953015289412905592.png
#
#                                  image_2_path  \
# 9                                        <NA>
# 11     dataset/images/2587768503558995392.png
# 23    dataset/images/-3253987854671575512.png
# 25                                       <NA>
# 35    dataset/images/-6233451743223829948.png
# ...                                       ...
# 4977                                     <NA>
# 4984  dataset/images/-7141594063372177636.png
# 5016  dataset/images/-8048467112742368195.png
# 5018                                     <NA>
# 5032                                     <NA>
#
#                                  image_3_path image_1_shot_type  \
# 9                                        <NA>          CLOSE_UP
# 11     dataset/images/5836170508263925618.png          CLOSE_UP
# 23      dataset/images/108462233489916244.png          CLOSE_UP
# 25                                       <NA>          CLOSE_UP
# 35     dataset/images/-764324206369620251.png          CLOSE_UP
# ...                                       ...               ...
# 4977                                     <NA>          CLOSE_UP
# 4984  dataset/images/-8970062608215251005.png       AT_AN_ANGLE
# 5016   dataset/images/6371452221179710784.png          CLOSE_UP
# 5018                                     <NA>          CLOSE_UP
# 5032                                     <NA>          CLOSE_UP
#
#      image_2_shot_type image_3_shot_type                     combined_race  \
# 9                 <NA>              <NA>                              <NA>
# 11         AT_DISTANCE       AT_AN_ANGLE                              <NA>
# 23         AT_DISTANCE       AT_AN_ANGLE                              <NA>
# 25                <NA>              <NA>                              <NA>
# 35         AT_DISTANCE       AT_AN_ANGLE                              <NA>
# ...                ...               ...                               ...
# 4977              <NA>              <NA>                              <NA>
# 4984          CLOSE_UP       AT_DISTANCE                              <NA>
# 5016       AT_AN_ANGLE       AT_DISTANCE                             WHITE
# 5018              <NA>              <NA>                              <NA>
# 5032              <NA>              <NA>  AMERICAN_INDIAN_OR_ALASKA_NATIVE
#
#                condition_1  confidence_1  avg_skin_type skin_type_category
# 9                  Purpura           1.0            4.0              brown
# 11               Urticaria           1.0            3.0               fair
# 23               Urticaria           1.0            NaN               <NA>
# 25                  Eczema           1.0            3.0               fair
# 35                  Eczema           1.0            3.0               fair
# ...                    ...           ...            ...                ...
# 4977  Chicken pox exanthem           1.0            2.0              white
# 4984                Eczema           1.0            2.0              white
# 5016     Stasis Dermatitis           1.0            3.0               fair
# 5018             Psoriasis           1.0            3.0               fair
# 5032          Folliculitis           1.0            NaN               <NA>
#
# [655 rows x 13 columns]

# %%
## Adding the image count for each condition

# %%
def count_images(row):
    count = 0
    for path in [row['image_1_path'], row['image_2_path'], row['image_3_path']]:
        if pd.notna(path) and path.strip() != '':
            count += 1
    return count

# Apply this function and check the results
df_case_label['image_count'] = df_case_label.apply(count_images, axis=1)
print(df_case_label['image_count'].value_counts())
print(f"Total image count for Eczema: {df_case_label[df_case_label['condition_1'] == 'Eczema']['image_count'].sum()}")
# Count images for each condition
image_counts = df_case_label.groupby('condition_1').apply(lambda x: x.apply(count_images, axis=1).sum()).reset_index()
image_counts.columns = ['condition_1', 'image_count']

# Merge with the summary DataFrame
conditions_summary_final = condition_summary.merge(image_counts, on='condition_1', how='left')

# Fill NaN values with 0 for conditions that don't have any images
conditions_summary_final['image_count'] = conditions_summary_final['image_count'].fillna(0).astype(int)

# Calculate the average number of images per case
conditions_summary_final['avg_images_per_case'] = conditions_summary_final['image_count'] / conditions_summary_final['count']

# Round to 2 decimal places
conditions_summary_final['avg_images_per_case'] = conditions_summary_final['avg_images_per_case'].round(2)

# Sort the DataFrame by count in descending order
conditions_summary_final = conditions_summary_final.sort_values('count', ascending=False)

# Display the updated DataFrame
print(conditions_summary_final)
# Out:
# image_count
# 1    300
# 3    265
# 2     90
# Name: count, dtype: int64
# Total image count for Eczema: 272
#                      condition_1  count  percentage  image_count  \
# 0                         Eczema    312       16.67          272
# 1    Allergic Contact Dermatitis    192       10.26           79
# 2                      Urticaria    160        8.55          150
# 3                    Insect Bite    119        6.36           66
# 4                   Folliculitis     84        4.49           62
# ..                           ...    ...         ...          ...
# 113                    Chilblain      1        0.05            0
# 112               Skin infection      1        0.05            0
# 111      Erythema gyratum repens      1        0.05            0
# 110              Acne keloidalis      1        0.05            0
# 165         Chicken pox exanthem      1        0.05            1
#
#      avg_images_per_case
# 0                   0.87
# 1                   0.41
# 2                   0.94
# 3                   0.55
# 4                   0.74
# ..                   ...
# 113                 0.00
# 112                 0.00
# 111                 0.00
# 110                 0.00
# 165                 1.00
#
# [166 rows x 5 columns]
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_49918/648075689.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_case_label['image_count'] = df_case_label.apply(count_images, axis=1)

# %%
conditions_summary_final.to_csv('data/conditions_summary_final.csv')

# %%
def count_images(row):
    count = 0
    for path in [row['image_1_path'], row['image_2_path'], row['image_3_path']]:
        if pd.notna(path) and path.strip() != '':
            count += 1
    return count

# Apply this function and check the results
df_case_label['image_count'] = df_case_label.apply(count_images, axis=1)
print(df_case_label['image_count'].value_counts())
print(f"Total image count for Eczema: {df_case_label[df_case_label['condition_1'] == 'Eczema']['image_count'].sum()}")
# Out:
# image_count
# 1    300
# 3    265
# 2     90
# Name: count, dtype: int64
# Total image count for Eczema: 272
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_49918/1810453027.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_case_label['image_count'] = df_case_label.apply(count_images, axis=1)

# %%
# Count of Eczema cases
eczema_cases = df_case_label[df_case_label['condition_1'] == 'Eczema']
print(f"Number of Eczema cases: {len(eczema_cases)}")

# Distribution of image counts for Eczema cases
print("Image count distribution for Eczema cases:")
print(eczema_cases['image_count'].value_counts())

# Check for Eczema cases with no images
eczema_no_images = eczema_cases[eczema_cases['image_count'] == 0]
print(f"Number of Eczema cases with no images: {len(eczema_no_images)}")

# If there are Eczema cases with no images, let's look at a few
if len(eczema_no_images) > 0:
    print("Sample of Eczema cases with no images:")
    print(eczema_no_images[['case_id', 'image_1_path', 'image_2_path', 'image_3_path']].head())
# Out:
# Number of Eczema cases: 123
# Image count distribution for Eczema cases:
# image_count
# 3    65
# 1    39
# 2    19
# Name: count, dtype: int64
# Number of Eczema cases with no images: 0
