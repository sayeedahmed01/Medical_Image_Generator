# %%
import pandas as pd

# %%
# Load the data

# %%
case_labels = pd.read_csv('case_label_filtered.csv')

# %%
condition_summary = pd.DataFrame({
    'count': case_labels['condition_1'].value_counts(),
    'percentage': case_labels['condition_1'].value_counts(normalize=True) * 100
})

# Round the percentage to two decimal places
condition_summary['percentage'] = condition_summary['percentage'].round(2)

# Sort by count in descending order
condition_summary = condition_summary.sort_values('count', ascending=False)

print(condition_summary.head(50))
# Out:
#                                          count  percentage
# condition_1
# Eczema                                     123       18.78
# Urticaria                                   81       12.37
# Allergic Contact Dermatitis                 41        6.26
# Folliculitis                                34        5.19
# Insect Bite                                 29        4.43
# Acute dermatitis, NOS                       26        3.97
# O/E - ecchymoses present                    20        3.05
# Herpes Zoster                               18        2.75
# Herpes Simplex                              16        2.44
# Psoriasis                                   16        2.44
# Acne                                        14        2.14
# Chronic dermatitis, NOS                     11        1.68
# Tinea Versicolor                            11        1.68
# Irritant Contact Dermatitis                 11        1.68
# Tinea                                       11        1.68
# Pigmented purpuric eruption                 10        1.53
# Leukocytoclastic Vasculitis                  9        1.37
# Purpura                                      9        1.37
# Acute and chronic dermatitis                 9        1.37
# Granuloma annulare                           9        1.37
# Impetigo                                     7        1.07
# Molluscum Contagiosum                        7        1.07
# Rosacea                                      6        0.92
# CD - Contact dermatitis                      6        0.92
# Seborrheic Dermatitis                        5        0.76
# Scar Condition                               5        0.76
# Verruca vulgaris                             5        0.76
# Perioral Dermatitis                          5        0.76
# Stasis Dermatitis                            5        0.76
# Confluent and reticulate papillomatosis      4        0.61
# Hidradenitis                                 4        0.61
# Actinic Keratosis                            4        0.61
# Erythema multiforme                          4        0.61
# Keratosis pilaris                            4        0.61
# Lichen Simplex Chronicus                     3        0.46
# Abscess                                      3        0.46
# Prurigo nodularis                            3        0.46
# Pityriasis rosea                             3        0.46
# Idiopathic guttate hypomelanosis             2        0.31
# Paronychia                                   2        0.31
# Hemangioma                                   2        0.31
# Cutaneous larva migrans                      2        0.31
# Miliaria                                     2        0.31
# Erythema ab igne                             2        0.31
# Drug Rash                                    2        0.31
# Xerosis                                      2        0.31
# Photodermatitis                              2        0.31
# Lichen planus/lichenoid eruption             2        0.31
# Venous Stasis Ulcer                          2        0.31
# SCC/SCCIS                                    2        0.31

# %%
def count_images(row):
    count = 0
    for path in [row['image_1_path'], row['image_2_path'], row['image_3_path']]:
        if pd.notna(path) and path.strip() != '':
            count += 1
    return count

# Apply this function and check the results
case_labels['image_count'] = case_labels.apply(count_images, axis=1)
print(case_labels['image_count'].value_counts())
print(f"Total image count for Eczema: {case_labels[case_labels['condition_1'] == 'Eczema']['image_count'].sum()}")
# Count images for each condition
image_counts = case_labels.groupby('condition_1').apply(lambda x: x.apply(count_images, axis=1).sum()).reset_index()
image_counts.columns = ['condition_1', 'image_count']

# Merge with the summary DataFrame
conditions_summary_final = condition_summary.merge(image_counts, on='condition_1', how='left')

# Fill NaN values with 0 for conditions that don't have any images
conditions_summary_final['image_count'] = conditions_summary_final['image_count'].fillna(0).astype(int)

# Calculate the average number of images per case
conditions_summary_final['avg_images_per_case'] = conditions_summary_final['image_count'] / conditions_summary_final['count']

# Round to 2 decimal places
conditions_summary_final['avg_images_per_case'] = conditions_summary_final['avg_images_per_case'].round(2)

# Sort the DataFrame by count in descending order
conditions_summary_final = conditions_summary_final.sort_values('count', ascending=False)

# Display the updated DataFrame
print(conditions_summary_final)
# Out:
# image_count
# 1    300
# 3    265
# 2     90
# Name: count, dtype: int64
# Total image count for Eczema: 272
#                           condition_1  count  percentage  image_count  \
# 0                              Eczema    123       18.78          272
# 1                           Urticaria     81       12.37          150
# 2         Allergic Contact Dermatitis     41        6.26           79
# 3                        Folliculitis     34        5.19           62
# 4                         Insect Bite     29        4.43           66
# ..                                ...    ...         ...          ...
# 63  Lichenified eczematous dermatitis      1        0.15            3
# 64                  Traumatic blister      1        0.15            1
# 65  Varicose veins of lower extremity      1        0.15            1
# 66                              Milia      1        0.15            3
# 89               Chicken pox exanthem      1        0.15            1
#
#     avg_images_per_case
# 0                  2.21
# 1                  1.85
# 2                  1.93
# 3                  1.82
# 4                  2.28
# ..                  ...
# 63                 3.00
# 64                 1.00
# 65                 1.00
# 66                 3.00
# 89                 1.00
#
# [90 rows x 5 columns]

# %%
conditions_summary_final.sort_values('image_count', ascending=False)
# Out:
#                     condition_1  count  percentage  image_count  \
# 0                        Eczema    123       18.78          272
# 1                     Urticaria     81       12.37          150
# 2   Allergic Contact Dermatitis     41        6.26           79
# 4                   Insect Bite     29        4.43           66
# 3                  Folliculitis     34        5.19           62
# ..                          ...    ...         ...          ...
# 75        Elephantiasis nostras      1        0.15            1
# 70       Vasculitis of the skin      1        0.15            1
# 81              Epidermal nevus      1        0.15            1
# 80      O/E - petechiae present      1        0.15            1
# 89         Chicken pox exanthem      1        0.15            1
#
#     avg_images_per_case
# 0                  2.21
# 1                  1.85
# 2                  1.93
# 4                  2.28
# 3                  1.82
# ..                  ...
# 75                 1.00
# 70                 1.00
# 81                 1.00
# 80                 1.00
# 89                 1.00
#
# [90 rows x 5 columns]

# %%
conditions_summary_final.reset_index(drop=True, inplace=True)

# %%
conditions_summary_final
# Out:
#                           condition_1  count  percentage  image_count  \
# 0                              Eczema    123       18.78          272
# 1                           Urticaria     81       12.37          150
# 2         Allergic Contact Dermatitis     41        6.26           79
# 3                        Folliculitis     34        5.19           62
# 4                         Insect Bite     29        4.43           66
# ..                                ...    ...         ...          ...
# 85  Lichenified eczematous dermatitis      1        0.15            3
# 86                  Traumatic blister      1        0.15            1
# 87  Varicose veins of lower extremity      1        0.15            1
# 88                              Milia      1        0.15            3
# 89               Chicken pox exanthem      1        0.15            1
#
#     avg_images_per_case
# 0                  2.21
# 1                  1.85
# 2                  1.93
# 3                  1.82
# 4                  2.28
# ..                  ...
# 85                 3.00
# 86                 1.00
# 87                 1.00
# 88                 3.00
# 89                 1.00
#
# [90 rows x 5 columns]

# %%
# Save the summary to a CSV file
conditions_summary_final.to_csv('conditions_summary.csv', index=False)

# %%
case_labels
# Out:
#                  case_id    body_part  \
# 0   -1022162013984621110          NaN
# 1   -1033431645373513522          NaN
# 2   -1073544188024944010          NaN
# 3   -1079717215777778516          NaN
# 4   -1120481478267460560          leg
# ..                   ...          ...
# 650  9094416934450217084          NaN
# 651  9105346707210308949          arm
# 652   930124461134778983          leg
# 653   935346003160692168          NaN
# 654   998890198757718998  torso_front
#
#                                 image_1_path  \
# 0     dataset/images/8406712750126834903.png
# 1    dataset/images/-1677898261371801194.png
# 2    dataset/images/-1542787778564695920.png
# 3    dataset/images/-3060870142909393201.png
# 4    dataset/images/-3933475004882152757.png
# ..                                       ...
# 650  dataset/images/-4639546377033199002.png
# 651  dataset/images/-3238683302029267521.png
# 652  dataset/images/-2787315420624607465.png
# 653  dataset/images/-8779903138873713227.png
# 654   dataset/images/8953015289412905592.png
#
#                                 image_2_path  \
# 0                                        NaN
# 1     dataset/images/2587768503558995392.png
# 2    dataset/images/-3253987854671575512.png
# 3                                        NaN
# 4    dataset/images/-6233451743223829948.png
# ..                                       ...
# 650                                      NaN
# 651  dataset/images/-7141594063372177636.png
# 652  dataset/images/-8048467112742368195.png
# 653                                      NaN
# 654                                      NaN
#
#                                 image_3_path image_1_shot_type  \
# 0                                        NaN          CLOSE_UP
# 1     dataset/images/5836170508263925618.png          CLOSE_UP
# 2      dataset/images/108462233489916244.png          CLOSE_UP
# 3                                        NaN          CLOSE_UP
# 4     dataset/images/-764324206369620251.png          CLOSE_UP
# ..                                       ...               ...
# 650                                      NaN          CLOSE_UP
# 651  dataset/images/-8970062608215251005.png       AT_AN_ANGLE
# 652   dataset/images/6371452221179710784.png          CLOSE_UP
# 653                                      NaN          CLOSE_UP
# 654                                      NaN          CLOSE_UP
#
#     image_2_shot_type image_3_shot_type                     combined_race  \
# 0                 NaN               NaN                               NaN
# 1         AT_DISTANCE       AT_AN_ANGLE                               NaN
# 2         AT_DISTANCE       AT_AN_ANGLE                               NaN
# 3                 NaN               NaN                               NaN
# 4         AT_DISTANCE       AT_AN_ANGLE                               NaN
# ..                ...               ...                               ...
# 650               NaN               NaN                               NaN
# 651          CLOSE_UP       AT_DISTANCE                               NaN
# 652       AT_AN_ANGLE       AT_DISTANCE                             WHITE
# 653               NaN               NaN                               NaN
# 654               NaN               NaN  AMERICAN_INDIAN_OR_ALASKA_NATIVE
#
#               condition_1  confidence_1  avg_skin_type skin_type_category  \
# 0                 Purpura           1.0            4.0              brown
# 1               Urticaria           1.0            3.0               fair
# 2               Urticaria           1.0            NaN                NaN
# 3                  Eczema           1.0            3.0               fair
# 4                  Eczema           1.0            3.0               fair
# ..                    ...           ...            ...                ...
# 650  Chicken pox exanthem           1.0            2.0              white
# 651                Eczema           1.0            2.0              white
# 652     Stasis Dermatitis           1.0            3.0               fair
# 653             Psoriasis           1.0            3.0               fair
# 654          Folliculitis           1.0            NaN                NaN
#
#      image_count
# 0              1
# 1              3
# 2              3
# 3              1
# 4              3
# ..           ...
# 650            1
# 651            3
# 652            3
# 653            1
# 654            1
#
# [655 rows x 14 columns]

# %%
filtered_case_labels = case_labels[case_labels['condition_1'].isin([
    'Eczema',
    'Urticaria',
    'Allergic Contact Dermatitis',
    'Folliculitis',
    'Acne',
    'Psoriasis',
    'Herpes Simplex',
    'Herpes Zoster',
    'Tinea',
    'Atopic Dermatitis'
])]

# %%
filtered_case_labels
# Out:
#                  case_id         body_part  \
# 1   -1033431645373513522               NaN
# 2   -1073544188024944010               NaN
# 3   -1079717215777778516               NaN
# 4   -1120481478267460560               leg
# 6   -1204349630028029673  foot_top_or_side
# ..                   ...               ...
# 647  9055010458301656007               arm
# 649  9079077127826406933               arm
# 651  9105346707210308949               arm
# 653   935346003160692168               NaN
# 654   998890198757718998       torso_front
#
#                                 image_1_path  \
# 1    dataset/images/-1677898261371801194.png
# 2    dataset/images/-1542787778564695920.png
# 3    dataset/images/-3060870142909393201.png
# 4    dataset/images/-3933475004882152757.png
# 6    dataset/images/-3136247653193336048.png
# ..                                       ...
# 647   dataset/images/-862558295135857219.png
# 649  dataset/images/-5432546180216775741.png
# 651  dataset/images/-3238683302029267521.png
# 653  dataset/images/-8779903138873713227.png
# 654   dataset/images/8953015289412905592.png
#
#                                 image_2_path  \
# 1     dataset/images/2587768503558995392.png
# 2    dataset/images/-3253987854671575512.png
# 3                                        NaN
# 4    dataset/images/-6233451743223829948.png
# 6                                        NaN
# ..                                       ...
# 647   dataset/images/6837737674648343890.png
# 649  dataset/images/-7343000754918930454.png
# 651  dataset/images/-7141594063372177636.png
# 653                                      NaN
# 654                                      NaN
#
#                                 image_3_path image_1_shot_type  \
# 1     dataset/images/5836170508263925618.png          CLOSE_UP
# 2      dataset/images/108462233489916244.png          CLOSE_UP
# 3                                        NaN          CLOSE_UP
# 4     dataset/images/-764324206369620251.png          CLOSE_UP
# 6                                        NaN          CLOSE_UP
# ..                                       ...               ...
# 647   dataset/images/8795885615476833533.png          CLOSE_UP
# 649   dataset/images/2021255960758992412.png       AT_DISTANCE
# 651  dataset/images/-8970062608215251005.png       AT_AN_ANGLE
# 653                                      NaN          CLOSE_UP
# 654                                      NaN          CLOSE_UP
#
#     image_2_shot_type image_3_shot_type                     combined_race  \
# 1         AT_DISTANCE       AT_AN_ANGLE                               NaN
# 2         AT_DISTANCE       AT_AN_ANGLE                               NaN
# 3                 NaN               NaN                               NaN
# 4         AT_DISTANCE       AT_AN_ANGLE                               NaN
# 6                 NaN               NaN                               NaN
# ..                ...               ...                               ...
# 647       AT_DISTANCE       AT_AN_ANGLE                               NaN
# 649          CLOSE_UP       AT_AN_ANGLE                             WHITE
# 651          CLOSE_UP       AT_DISTANCE                               NaN
# 653               NaN               NaN                               NaN
# 654               NaN               NaN  AMERICAN_INDIAN_OR_ALASKA_NATIVE
#
#       condition_1  confidence_1  avg_skin_type skin_type_category  image_count
# 1       Urticaria           1.0            3.0               fair            3
# 2       Urticaria           1.0            NaN                NaN            3
# 3          Eczema           1.0            3.0               fair            1
# 4          Eczema           1.0            3.0               fair            3
# 6           Tinea           1.0            3.0               fair            1
# ..            ...           ...            ...                ...          ...
# 647        Eczema           1.0            4.0              brown            3
# 649        Eczema           1.0            3.0               fair            3
# 651        Eczema           1.0            2.0              white            3
# 653     Psoriasis           1.0            3.0               fair            1
# 654  Folliculitis           1.0            NaN                NaN            1
#
# [354 rows x 14 columns]

# %%
len(filtered_case_labels)
# Out:
# 354

# %%
# Moving images to the training data directory

# %%
import os
import shutil
# Base directory for the training data
base_dir = 'train_data'

# Ensure the base directory exists
os.makedirs(base_dir, exist_ok=True)

# Function to move an image if it exists
def move_image(src, dst):
    if os.path.exists(src):
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.move(src, dst)
        print(f"Moved {src} to {dst}")
    else:
        print(f"File not found: {src}")

# Iterate through the filtered dataframe
for index, row in filtered_case_labels.iterrows():
    condition = row['condition_1']
    condition_dir = os.path.join(base_dir, condition)

    # Ensure the condition directory exists
    os.makedirs(condition_dir, exist_ok=True)

    # Move images if they exist
    for i in range(1, 4):  # We have up to 3 images per case
        image_path = row.get(f'image_{i}_path')
        if pd.notna(image_path):
            new_path = os.path.join(condition_dir, os.path.basename(image_path))
            move_image(image_path, new_path)

print("Image moving process completed.")
# Out:
# Moved dataset/images/-1677898261371801194.png to train_data/Urticaria/-1677898261371801194.png
# Moved dataset/images/2587768503558995392.png to train_data/Urticaria/2587768503558995392.png
# Moved dataset/images/5836170508263925618.png to train_data/Urticaria/5836170508263925618.png
# Moved dataset/images/-1542787778564695920.png to train_data/Urticaria/-1542787778564695920.png
# Moved dataset/images/-3253987854671575512.png to train_data/Urticaria/-3253987854671575512.png
# Moved dataset/images/108462233489916244.png to train_data/Urticaria/108462233489916244.png
# Moved dataset/images/-3060870142909393201.png to train_data/Eczema/-3060870142909393201.png
# Moved dataset/images/-3933475004882152757.png to train_data/Eczema/-3933475004882152757.png
# Moved dataset/images/-6233451743223829948.png to train_data/Eczema/-6233451743223829948.png
# Moved dataset/images/-764324206369620251.png to train_data/Eczema/-764324206369620251.png
# Moved dataset/images/-3136247653193336048.png to train_data/Tinea/-3136247653193336048.png
# Moved dataset/images/8992004962400932960.png to train_data/Psoriasis/8992004962400932960.png
# Moved dataset/images/-8383531997336683331.png to train_data/Eczema/-8383531997336683331.png
# Moved dataset/images/6319795661728367224.png to train_data/Eczema/6319795661728367224.png
# Moved dataset/images/7903520447837776507.png to train_data/Eczema/7903520447837776507.png
# Moved dataset/images/1323541714731364649.png to train_data/Urticaria/1323541714731364649.png
# Moved dataset/images/4761491203812701728.png to train_data/Urticaria/4761491203812701728.png
# Moved dataset/images/8775618016429057914.png to train_data/Urticaria/8775618016429057914.png
# Moved dataset/images/-2641434887280849554.png to train_data/Acne/-2641434887280849554.png
# Moved dataset/images/-2367385470888041402.png to train_data/Eczema/-2367385470888041402.png
# Moved dataset/images/325464533153467313.png to train_data/Eczema/325464533153467313.png
# Moved dataset/images/-5521011744040552037.png to train_data/Allergic Contact Dermatitis/-5521011744040552037.png
# Moved dataset/images/5937000031772480607.png to train_data/Allergic Contact Dermatitis/5937000031772480607.png
# Moved dataset/images/-8800789120959035521.png to train_data/Herpes Zoster/-8800789120959035521.png
# Moved dataset/images/8576258398425923001.png to train_data/Eczema/8576258398425923001.png
# Moved dataset/images/6292696424741890887.png to train_data/Folliculitis/6292696424741890887.png
# Moved dataset/images/-3744623047411140376.png to train_data/Herpes Simplex/-3744623047411140376.png
# Moved dataset/images/-60191807411945794.png to train_data/Herpes Simplex/-60191807411945794.png
# Moved dataset/images/2761011390199798183.png to train_data/Herpes Simplex/2761011390199798183.png
# Moved dataset/images/-454976303503844455.png to train_data/Tinea/-454976303503844455.png
# Moved dataset/images/60032766606288611.png to train_data/Tinea/60032766606288611.png
# Moved dataset/images/6266104663802047097.png to train_data/Eczema/6266104663802047097.png
# Moved dataset/images/-7461895286563712603.png to train_data/Eczema/-7461895286563712603.png
# Moved dataset/images/1826477474008192497.png to train_data/Eczema/1826477474008192497.png
# Moved dataset/images/1281951106283171619.png to train_data/Urticaria/1281951106283171619.png
# Moved dataset/images/-862558295135857219.png to train_data/Eczema/-862558295135857219.png
# Moved dataset/images/6837737674648343890.png to train_data/Eczema/6837737674648343890.png
# Moved dataset/images/8795885615476833533.png to train_data/Eczema/8795885615476833533.png
# Moved dataset/images/-5432546180216775741.png to train_data/Eczema/-5432546180216775741.png
# Moved dataset/images/-7343000754918930454.png to train_data/Eczema/-7343000754918930454.png
# Moved dataset/images/2021255960758992412.png to train_data/Eczema/2021255960758992412.png
# Moved dataset/images/-3238683302029267521.png to train_data/Eczema/-3238683302029267521.png
# Moved dataset/images/-7141594063372177636.png to train_data/Eczema/-7141594063372177636.png
# Moved dataset/images/-8970062608215251005.png to train_data/Eczema/-8970062608215251005.png
# Moved dataset/images/-8779903138873713227.png to train_data/Psoriasis/-8779903138873713227.png
# Moved dataset/images/8953015289412905592.png to train_data/Folliculitis/8953015289412905592.png
# Image moving process completed.

# %%
import pandas as pd
tagged_images = pd.read_csv('image_tags.csv')

# %%
tagged_images
# Out:
#                                             Image Path       Condition  \
# 0    train_data/Herpes Simplex/-4548551644236086193...  Herpes Simplex
# 1    train_data/Herpes Simplex/8938987404946448422.png  Herpes Simplex
# 2    train_data/Herpes Simplex/-1340575480650711275...  Herpes Simplex
# 3    train_data/Herpes Simplex/-1545090829447090603...  Herpes Simplex
# 4    train_data/Herpes Simplex/2761011390199798183.png  Herpes Simplex
# ..                                                 ...             ...
# 432    train_data/Folliculitis/2432074176479085493.png    Folliculitis
# 433    train_data/Folliculitis/1633175637881662694.png    Folliculitis
# 434   train_data/Folliculitis/-3334185101988508211.png    Folliculitis
# 435    train_data/Folliculitis/-487619432479533708.png    Folliculitis
# 436    train_data/Folliculitis/7980844269689605309.png    Folliculitis
#
#     Body Part
# 0        Arms
# 1        Neck
# 2        Arms
# 3       Hands
# 4        Legs
# ..        ...
# 432     Other
# 433      Neck
# 434     Other
# 435      Legs
# 436     Other
#
# [437 rows x 3 columns]

# %%
# Populating the tagged image data with condition labels

# %%
import pandas as pd

def clean_image_path(path, prefix_to_remove):
    if path and isinstance(path, str):
        return path.replace(prefix_to_remove, '')
    return path

def find_matching_row(image_path, filtered_df):
    # Remove 'train_data/' and everything up to the next '/' from tagged_images path
    cleaned_tagged_image_path = '/'.join(image_path.split('/')[2:])

    for _, row in filtered_df.iterrows():
        for i in range(1, 4):
            col_name = f'image_{i}_path'
            if col_name in row and row[col_name]:
                # Remove 'dataset/images/' from filtered_case_labels path
                cleaned_filtered_image_path = clean_image_path(row[col_name], 'dataset/images/')
                if cleaned_tagged_image_path == cleaned_filtered_image_path:
                    return {
                        'case_id': row['case_id'],
                        'image_shot_type': row[f'image_{i}_shot_type'],
                        'combined_race': row['combined_race'],
                        'skin_type_category': row['skin_type_category']
                    }
    return {
        'case_id': None,
        'image_shot_type': None,
        'combined_race': None,
        'skin_type_category': None
    }

# Clean the image paths in filtered_case_labels
for col in ['image_1_path', 'image_2_path', 'image_3_path']:
    filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))

# Apply the function to each row in tagged_images
tagged_images[['case_id', 'image_shot_type', 'combined_race', 'skin_type_category']] = tagged_images['Image Path'].apply(
    lambda x: pd.Series(find_matching_row(x, filtered_case_labels))
)

# Display the updated tagged_images dataframe
print(tagged_images)
# Out:
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_69782/3173411651.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_69782/3173411651.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_69782/3173411651.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))
#                                             Image Path       Condition  \
# 0    train_data/Herpes Simplex/-4548551644236086193...  Herpes Simplex
# 1    train_data/Herpes Simplex/8938987404946448422.png  Herpes Simplex
# 2    train_data/Herpes Simplex/-1340575480650711275...  Herpes Simplex
# 3    train_data/Herpes Simplex/-1545090829447090603...  Herpes Simplex
# 4    train_data/Herpes Simplex/2761011390199798183.png  Herpes Simplex
# ..                                                 ...             ...
# 432    train_data/Folliculitis/2432074176479085493.png    Folliculitis
# 433    train_data/Folliculitis/1633175637881662694.png    Folliculitis
# 434   train_data/Folliculitis/-3334185101988508211.png    Folliculitis
# 435    train_data/Folliculitis/-487619432479533708.png    Folliculitis
# 436    train_data/Folliculitis/7980844269689605309.png    Folliculitis
#
#     Body Part              case_id image_shot_type              combined_race  \
# 0        Arms -7637240478939124697        CLOSE_UP                      WHITE
# 1        Neck  2084479032845321772     AT_DISTANCE                        NaN
# 2        Arms -2298741642819106068     AT_DISTANCE  BLACK_OR_AFRICAN_AMERICAN
# 3       Hands  8290822761716679927     AT_DISTANCE                      WHITE
# 4        Legs   868379715655855009     AT_DISTANCE                      WHITE
# ..        ...                  ...             ...                        ...
# 432     Other -4681186898904271014        CLOSE_UP                        NaN
# 433      Neck -7432151961683759568     AT_AN_ANGLE                        NaN
# 434     Other   597372832999055528        CLOSE_UP                      WHITE
# 435      Legs  3905100936130110268     AT_DISTANCE                        NaN
# 436     Other  2346463657328001892        CLOSE_UP                      WHITE
#
#     skin_type_category
# 0                white
# 1                brown
# 2                brown
# 3                 fair
# 4                 fair
# ..                 ...
# 432              white
# 433               fair
# 434               fair
# 435               fair
# 436               fair
#
# [437 rows x 7 columns]

# %%
tagged_images
# Out:
#                                             Image Path       Condition  \
# 0    train_data/Herpes Simplex/-4548551644236086193...  Herpes Simplex
# 1    train_data/Herpes Simplex/8938987404946448422.png  Herpes Simplex
# 2    train_data/Herpes Simplex/-1340575480650711275...  Herpes Simplex
# 3    train_data/Herpes Simplex/-1545090829447090603...  Herpes Simplex
# 4    train_data/Herpes Simplex/2761011390199798183.png  Herpes Simplex
# ..                                                 ...             ...
# 432    train_data/Folliculitis/2432074176479085493.png    Folliculitis
# 433    train_data/Folliculitis/1633175637881662694.png    Folliculitis
# 434   train_data/Folliculitis/-3334185101988508211.png    Folliculitis
# 435    train_data/Folliculitis/-487619432479533708.png    Folliculitis
# 436    train_data/Folliculitis/7980844269689605309.png    Folliculitis
#
#     Body Part              case_id image_shot_type              combined_race  \
# 0        Arms -7637240478939124697        CLOSE_UP                      WHITE
# 1        Neck  2084479032845321772     AT_DISTANCE                        NaN
# 2        Arms -2298741642819106068     AT_DISTANCE  BLACK_OR_AFRICAN_AMERICAN
# 3       Hands  8290822761716679927     AT_DISTANCE                      WHITE
# 4        Legs   868379715655855009     AT_DISTANCE                      WHITE
# ..        ...                  ...             ...                        ...
# 432     Other -4681186898904271014        CLOSE_UP                        NaN
# 433      Neck -7432151961683759568     AT_AN_ANGLE                        NaN
# 434     Other   597372832999055528        CLOSE_UP                      WHITE
# 435      Legs  3905100936130110268     AT_DISTANCE                        NaN
# 436     Other  2346463657328001892        CLOSE_UP                      WHITE
#
#     skin_type_category
# 0                white
# 1                brown
# 2                brown
# 3                 fair
# 4                 fair
# ..                 ...
# 432              white
# 433               fair
# 434               fair
# 435               fair
# 436               fair
#
# [437 rows x 7 columns]

# %%
tagged_images.dtypes
# Out:
# Image Path            object
# Condition             object
# Body Part             object
# case_id                int64
# image_shot_type       object
# combined_race         object
# skin_type_category    object
# dtype: object

# %%
tagged_images = tagged_images.reindex(columns=['case_id', 'Condition', 'Body Part', 'image_shot_type', 'combined_race', 'skin_type_category', 'Image Path'])

# %%
tagged_images
# Out:
#                  case_id       Condition Body Part image_shot_type  \
# 0   -7637240478939124697  Herpes Simplex      Arms        CLOSE_UP
# 1    2084479032845321772  Herpes Simplex      Neck     AT_DISTANCE
# 2   -2298741642819106068  Herpes Simplex      Arms     AT_DISTANCE
# 3    8290822761716679927  Herpes Simplex     Hands     AT_DISTANCE
# 4     868379715655855009  Herpes Simplex      Legs     AT_DISTANCE
# ..                   ...             ...       ...             ...
# 432 -4681186898904271014    Folliculitis     Other        CLOSE_UP
# 433 -7432151961683759568    Folliculitis      Neck     AT_AN_ANGLE
# 434   597372832999055528    Folliculitis     Other        CLOSE_UP
# 435  3905100936130110268    Folliculitis      Legs     AT_DISTANCE
# 436  2346463657328001892    Folliculitis     Other        CLOSE_UP
#
#                  combined_race skin_type_category  \
# 0                        WHITE              white
# 1                          NaN              brown
# 2    BLACK_OR_AFRICAN_AMERICAN              brown
# 3                        WHITE               fair
# 4                        WHITE               fair
# ..                         ...                ...
# 432                        NaN              white
# 433                        NaN               fair
# 434                      WHITE               fair
# 435                        NaN               fair
# 436                      WHITE               fair
#
#                                             Image Path
# 0    train_data/Herpes Simplex/-4548551644236086193...
# 1    train_data/Herpes Simplex/8938987404946448422.png
# 2    train_data/Herpes Simplex/-1340575480650711275...
# 3    train_data/Herpes Simplex/-1545090829447090603...
# 4    train_data/Herpes Simplex/2761011390199798183.png
# ..                                                 ...
# 432    train_data/Folliculitis/2432074176479085493.png
# 433    train_data/Folliculitis/1633175637881662694.png
# 434   train_data/Folliculitis/-3334185101988508211.png
# 435    train_data/Folliculitis/-487619432479533708.png
# 436    train_data/Folliculitis/7980844269689605309.png
#
# [437 rows x 7 columns]

# %%
tagged_images.to_csv('tagged_images_with_labels.csv', index=False)

# %%
tagged_images.groupby('Condition').count()
# Out:
#                              case_id  Body Part  image_shot_type  \
# Condition
# Acne                              24         24               24
# Allergic Contact Dermatitis       42         42               42
# Eczema                           137        137              137
# Folliculitis                      43         43               43
# Herpes Simplex                    21         21               21
# Herpes Zoster                     26         26               26
# Psoriasis                         27         27               27
# Tinea                             22         22               22
# Urticaria                         95         95               95
#
#                              combined_race  skin_type_category  Image Path
# Condition
# Acne                                    19                  24          24
# Allergic Contact Dermatitis             21                  40          42
# Eczema                                  56                 130         137
# Folliculitis                            28                  42          43
# Herpes Simplex                          14                  20          21
# Herpes Zoster                            6                  26          26
# Psoriasis                                6                  24          27
# Tinea                                   12                  18          22
# Urticaria                               46                  90          95

# %%
import csv
import os
import shutil

# Define the destination directory
dest_dir = 'training_imgs'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the CSV file
with open('tagged_images_with_labels.csv', 'r') as csvfile:
    csvreader = csv.DictReader(csvfile)

    # Iterate through each row in the CSV
    for row in csvreader:
        # Get the full image path
        source_path = row['Image Path']

        # Get just the filename
        filename = os.path.basename(source_path)

        # Construct the destination path
        dest_path = os.path.join(dest_dir, filename)

        # Move the file
        try:
            shutil.move(source_path, dest_path)
            print(f"Moved: {filename}")
        except FileNotFoundError:
            print(f"File not found: {source_path}")
        except Exception as e:
            print(f"Error moving {source_path}: {str(e)}")

print("File moving complete.")
# Out:
# Moved: -4548551644236086193.png
# Moved: 8938987404946448422.png
# Moved: -1340575480650711275.png
# Moved: -1545090829447090603.png
# Moved: 2761011390199798183.png
# Moved: 5158179525394239842.png
# Moved: 2377128044154932230.png
# Moved: 7836755757138392671.png
# Moved: 5997785294563888355.png
# Moved: 7958401754757491846.png
# Moved: -60191807411945794.png
# Moved: 2519585291032607145.png
# Moved: -8653997701010841176.png
# Moved: 8064981422824571519.png
# Moved: 7696350726318300806.png
# Moved: 3223640013662199890.png
# Moved: -2805054034077058173.png
# Moved: 1603224747391777244.png
# Moved: -1624415441092446149.png
# Moved: -5844628081699285197.png
# Moved: -8696744820413574401.png
# Moved: -6112700142679995455.png
# Moved: -6267939346252962600.png
# Moved: 6292696424741890887.png
# Moved: 5782906621323618567.png
# Moved: -2183262704807807048.png
# Moved: -3232676345267998411.png
# Moved: -4174491605367355580.png
# Moved: 3768000086218908353.png
# Moved: 2345398137409505013.png
# Moved: 5397545970881234398.png
# Moved: 3116486262777899251.png
# Moved: -2160150570103980686.png
# Moved: 7656458232116458862.png
# Moved: -8484522439451719694.png
# Moved: 1088819642810705043.png
# Moved: -1096173923758281940.png
# Moved: -2845520797762628017.png
# Moved: 6040966471554410144.png
# Moved: 8894388069855097864.png
# Moved: 2861479942276825836.png
# Moved: 1343985150496825534.png
# Moved: 8566741698855191136.png
# Moved: 383418029847586202.png
# Moved: 6698561070990105178.png
# Moved: 2432074176479085493.png
# Moved: 1633175637881662694.png
# Moved: -3334185101988508211.png
# Moved: -487619432479533708.png
# Moved: 7980844269689605309.png
# File moving complete.

# %%
tagged_images_1 = pd.read_csv('image_tags.csv')

# %%
import pandas as pd

def clean_image_path(path, prefix_to_remove):
    if path and isinstance(path, str):
        return path.replace(prefix_to_remove, '')
    return path

def find_matching_row(image_path, filtered_df):
    # Remove 'train_data/' and everything up to the next '/' from tagged_images path
    cleaned_tagged_image_path = '/'.join(image_path.split('/')[2:])

    for _, row in filtered_df.iterrows():
        for i in range(1, 4):
            col_name = f'image_{i}_path'
            if col_name in row and row[col_name]:
                # Remove 'dataset/images/' from filtered_case_labels path
                cleaned_filtered_image_path = clean_image_path(row[col_name], 'dataset/images/')
                if cleaned_tagged_image_path == cleaned_filtered_image_path:
                    return {
                        'case_id': row['case_id'],
                        'image_shot_type': row[f'image_{i}_shot_type'],
                        'combined_race': row['combined_race'],
                        'skin_type_category': row['skin_type_category']
                    }
    return {
        'case_id': None,
        'image_shot_type': None,
        'combined_race': None,
        'skin_type_category': None
    }

# Clean the image paths in filtered_case_labels
for col in ['image_1_path', 'image_2_path', 'image_3_path']:
    filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))

# Apply the function to each row in tagged_images
tagged_images_1[['case_id', 'image_shot_type', 'combined_race', 'skin_type_category']] = tagged_images_1['Image Path'].apply(
    lambda x: pd.Series(find_matching_row(x, filtered_case_labels))
)

# Display the updated tagged_images dataframe
print(tagged_images_1)
# Out:
#                                            Image Path  \
# 0           train_data/Tinea/-3443499009691532250.png
# 1   train_data/Allergic Contact Dermatitis/-532249...
# 2   train_data/Allergic Contact Dermatitis/-877882...
# 3   train_data/Allergic Contact Dermatitis/-431045...
# 4   train_data/Allergic Contact Dermatitis/3822050...
# 5   train_data/Allergic Contact Dermatitis/6060584...
# 6   train_data/Allergic Contact Dermatitis/1387639...
# 7   train_data/Allergic Contact Dermatitis/-676084...
# 8   train_data/Allergic Contact Dermatitis/6349646...
# 9   train_data/Allergic Contact Dermatitis/4785295...
# 10   train_data/Herpes Zoster/-722503728208176049.png
# 11   train_data/Herpes Zoster/5794288412787857146.png
# 12   train_data/Folliculitis/-3290459357811788031.png
#
#                       Condition Body Part              case_id  \
# 0                         Tinea     Other  8296549785436989539
# 1   Allergic Contact Dermatitis     Other -2483075134447987416
# 2   Allergic Contact Dermatitis     Other -6776518044035331491
# 3   Allergic Contact Dermatitis     Other  2600794538114860588
# 4   Allergic Contact Dermatitis     Other -4164508719774231343
# 5   Allergic Contact Dermatitis      Feet -6781948527342850071
# 6   Allergic Contact Dermatitis     Other -5946926520681878281
# 7   Allergic Contact Dermatitis     Other -5863256407851897110
# 8   Allergic Contact Dermatitis     Other -2518265086444700975
# 9   Allergic Contact Dermatitis     Hands  3231607339220548802
# 10                Herpes Zoster     Other  6050019040579522081
# 11                Herpes Zoster     Other -8409059137252391480
# 12                 Folliculitis     Other -4695767486983535562
#
#    image_shot_type              combined_race skin_type_category
# 0      AT_AN_ANGLE                      WHITE               fair
# 1         CLOSE_UP                        NaN              white
# 2      AT_AN_ANGLE                        NaN               fair
# 3         CLOSE_UP  BLACK_OR_AFRICAN_AMERICAN              brown
# 4         CLOSE_UP       PREFER_NOT_TO_ANSWER               fair
# 5         CLOSE_UP                        NaN               fair
# 6         CLOSE_UP                      WHITE              white
# 7         CLOSE_UP                        NaN              brown
# 8         CLOSE_UP                        NaN                NaN
# 9         CLOSE_UP                        NaN               fair
# 10     AT_AN_ANGLE                        NaN              white
# 11     AT_AN_ANGLE                        NaN               fair
# 12        CLOSE_UP                      WHITE               fair
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_69782/182654232.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_69782/182654232.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))
# /var/folders/r0/5kwf4dxn5kg1kyhqf3y62zh40000gn/T/ipykernel_69782/182654232.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_case_labels[col] = filtered_case_labels[col].apply(lambda x: clean_image_path(x, 'dataset/images/'))

# %%
tagged_images_1 = tagged_images_1.reindex(columns=['case_id', 'Condition', 'Body Part', 'image_shot_type', 'combined_race', 'skin_type_category', 'Image Path'])

# %%
tagged_images_1.to_csv('tagged_images_1_with_labels.csv', index=False)

# %%
import csv
import os
import shutil

# Define the destination directory
dest_dir = 'training_imgs'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the CSV file
with open('tagged_images_1_with_labels.csv', 'r') as csvfile:
    csvreader = csv.DictReader(csvfile)

    # Iterate through each row in the CSV
    for row in csvreader:
        # Get the full image path
        source_path = row['Image Path']

        # Get just the filename
        filename = os.path.basename(source_path)

        # Construct the destination path
        dest_path = os.path.join(dest_dir, filename)

        # Move the file
        try:
            shutil.move(source_path, dest_path)
            print(f"Moved: {filename}")
        except FileNotFoundError:
            print(f"File not found: {source_path}")
        except Exception as e:
            print(f"Error moving {source_path}: {str(e)}")

print("File moving complete.")
# Out:
# Moved: -3443499009691532250.png
# Moved: -532249905180848227.png
# Moved: -8778820166267554159.png
# Moved: -4310457434092779564.png
# Moved: 382205097892683569.png
# Moved: 6060584194970876159.png
# Moved: 1387639516796423603.png
# Moved: -6760849338709173764.png
# Moved: 6349646448404623907.png
# Moved: 4785295238614687170.png
# Moved: -722503728208176049.png
# Moved: 5794288412787857146.png
# Moved: -3290459357811788031.png
# File moving complete.

# %%
tagged_images._append(tagged_images_1)
# Out:
#                 case_id                    Condition Body Part  \
# 0  -7637240478939124697               Herpes Simplex      Arms
# 1   2084479032845321772               Herpes Simplex      Neck
# 2  -2298741642819106068               Herpes Simplex      Arms
# 3   8290822761716679927               Herpes Simplex     Hands
# 4    868379715655855009               Herpes Simplex      Legs
# ..                  ...                          ...       ...
# 8  -2518265086444700975  Allergic Contact Dermatitis     Other
# 9   3231607339220548802  Allergic Contact Dermatitis     Hands
# 10  6050019040579522081                Herpes Zoster     Other
# 11 -8409059137252391480                Herpes Zoster     Other
# 12 -4695767486983535562                 Folliculitis     Other
#
#    image_shot_type              combined_race skin_type_category  \
# 0         CLOSE_UP                      WHITE              white
# 1      AT_DISTANCE                        NaN              brown
# 2      AT_DISTANCE  BLACK_OR_AFRICAN_AMERICAN              brown
# 3      AT_DISTANCE                      WHITE               fair
# 4      AT_DISTANCE                      WHITE               fair
# ..             ...                        ...                ...
# 8         CLOSE_UP                        NaN                NaN
# 9         CLOSE_UP                        NaN               fair
# 10     AT_AN_ANGLE                        NaN              white
# 11     AT_AN_ANGLE                        NaN               fair
# 12        CLOSE_UP                      WHITE               fair
#
#                                            Image Path
# 0   train_data/Herpes Simplex/-4548551644236086193...
# 1   train_data/Herpes Simplex/8938987404946448422.png
# 2   train_data/Herpes Simplex/-1340575480650711275...
# 3   train_data/Herpes Simplex/-1545090829447090603...
# 4   train_data/Herpes Simplex/2761011390199798183.png
# ..                                                ...
# 8   train_data/Allergic Contact Dermatitis/6349646...
# 9   train_data/Allergic Contact Dermatitis/4785295...
# 10   train_data/Herpes Zoster/-722503728208176049.png
# 11   train_data/Herpes Zoster/5794288412787857146.png
# 12   train_data/Folliculitis/-3290459357811788031.png
#
# [450 rows x 7 columns]

# %%
tagged_images.groupby('Condition').count()
# Out:
#                              case_id  Body Part  image_shot_type  \
# Condition
# Acne                              24         24               24
# Allergic Contact Dermatitis       42         42               42
# Eczema                           137        137              137
# Folliculitis                      43         43               43
# Herpes Simplex                    21         21               21
# Herpes Zoster                     26         26               26
# Psoriasis                         27         27               27
# Tinea                             22         22               22
# Urticaria                         95         95               95
#
#                              combined_race  skin_type_category  Image Path
# Condition
# Acne                                    19                  24          24
# Allergic Contact Dermatitis             21                  40          42
# Eczema                                  56                 130         137
# Folliculitis                            28                  42          43
# Herpes Simplex                          14                  20          21
# Herpes Zoster                            6                  26          26
# Psoriasis                                6                  24          27
# Tinea                                   12                  18          22
# Urticaria                               46                  90          95

# %%
print(tagged_images)
# Out:
#                  case_id       Condition Body Part image_shot_type  \
# 0   -7637240478939124697  Herpes Simplex      Arms        CLOSE_UP
# 1    2084479032845321772  Herpes Simplex      Neck     AT_DISTANCE
# 2   -2298741642819106068  Herpes Simplex      Arms     AT_DISTANCE
# 3    8290822761716679927  Herpes Simplex     Hands     AT_DISTANCE
# 4     868379715655855009  Herpes Simplex      Legs     AT_DISTANCE
# ..                   ...             ...       ...             ...
# 432 -4681186898904271014    Folliculitis     Other        CLOSE_UP
# 433 -7432151961683759568    Folliculitis      Neck     AT_AN_ANGLE
# 434   597372832999055528    Folliculitis     Other        CLOSE_UP
# 435  3905100936130110268    Folliculitis      Legs     AT_DISTANCE
# 436  2346463657328001892    Folliculitis     Other        CLOSE_UP
#
#                  combined_race skin_type_category  \
# 0                        WHITE              white
# 1                          NaN              brown
# 2    BLACK_OR_AFRICAN_AMERICAN              brown
# 3                        WHITE               fair
# 4                        WHITE               fair
# ..                         ...                ...
# 432                        NaN              white
# 433                        NaN               fair
# 434                      WHITE               fair
# 435                        NaN               fair
# 436                      WHITE               fair
#
#                                             Image Path
# 0    train_data/Herpes Simplex/-4548551644236086193...
# 1    train_data/Herpes Simplex/8938987404946448422.png
# 2    train_data/Herpes Simplex/-1340575480650711275...
# 3    train_data/Herpes Simplex/-1545090829447090603...
# 4    train_data/Herpes Simplex/2761011390199798183.png
# ..                                                 ...
# 432    train_data/Folliculitis/2432074176479085493.png
# 433    train_data/Folliculitis/1633175637881662694.png
# 434   train_data/Folliculitis/-3334185101988508211.png
# 435    train_data/Folliculitis/-487619432479533708.png
# 436    train_data/Folliculitis/7980844269689605309.png
#
# [437 rows x 7 columns]

# %%
tagged_images.dtypes
# Out:
# case_id                int64
# Condition             object
# Body Part             object
# image_shot_type       object
# combined_race         object
# skin_type_category    object
# Image Path            object
# dtype: object

# %%
for column in tagged_images.columns:
    if column != 'case_id':
        tagged_images[column] = tagged_images[column].astype(str)
        
tagged_images.dtypes
# Out:
# case_id                int64
# Condition             object
# Body Part             object
# image_shot_type       object
# combined_race         object
# skin_type_category    object
# Image Path            object
# dtype: object

# %%
# Function to generate the text description
def generate_text(row):
    if row['Body Part'].lower() == 'other':
        return f"a {row['image_shot_type'].lower()} photo of {row['Condition'].lower()} skin condition on {row['skin_type_category'].lower()} skin"
    else:
        return f"a {row['image_shot_type'].lower()} photo of {row['Condition'].lower()} skin condition on {row['Body Part'].lower()} on {row['skin_type_category'].lower()} skin"

# Create a new DataFrame for metadata
metadata = pd.DataFrame()

# Process the image path
metadata['image_path'] = tagged_images['Image Path'].apply(lambda x: 'training_imgs/' + os.path.basename(x))

# Generate the text description
metadata['text'] = tagged_images.apply(generate_text, axis=1)

# Save the new DataFrame to a CSV file
metadata.to_csv('metadata.csv', index=False)

print("metadata.csv has been created successfully.")
# Out:
# metadata.csv has been created successfully.

# %%
def remove_underscores(text):
    return text.replace('_', ' ')

# Apply the function to the 'text' column
metadata['text'] = metadata['text'].apply(remove_underscores)

# %%
metadata
# Out:
#                                  image_path  \
# 0    training_imgs/-4548551644236086193.png
# 1     training_imgs/8938987404946448422.png
# 2    training_imgs/-1340575480650711275.png
# 3    training_imgs/-1545090829447090603.png
# 4     training_imgs/2761011390199798183.png
# ..                                      ...
# 432   training_imgs/2432074176479085493.png
# 433   training_imgs/1633175637881662694.png
# 434  training_imgs/-3334185101988508211.png
# 435   training_imgs/-487619432479533708.png
# 436   training_imgs/7980844269689605309.png
#
#                                                   text
# 0    a close up photo of herpes simplex skin condit...
# 1    a at distance photo of herpes simplex skin con...
# 2    a at distance photo of herpes simplex skin con...
# 3    a at distance photo of herpes simplex skin con...
# 4    a at distance photo of herpes simplex skin con...
# ..                                                 ...
# 432  a close up photo of folliculitis skin conditio...
# 433  a at an angle photo of folliculitis skin condi...
# 434  a close up photo of folliculitis skin conditio...
# 435  a at distance photo of folliculitis skin condi...
# 436  a close up photo of folliculitis skin conditio...
#
# [437 rows x 2 columns]

# %%
metadata.to_csv('metadata.csv', index=False)

# %%
metadata = pd.read_csv('metadata.csv')

# %%
metadata
# Out:
#                                  image_path  \
# 0    training_imgs/-4548551644236086193.png
# 1     training_imgs/8938987404946448422.png
# 2    training_imgs/-1340575480650711275.png
# 3    training_imgs/-1545090829447090603.png
# 4     training_imgs/2761011390199798183.png
# ..                                      ...
# 432   training_imgs/2432074176479085493.png
# 433   training_imgs/1633175637881662694.png
# 434  training_imgs/-3334185101988508211.png
# 435   training_imgs/-487619432479533708.png
# 436   training_imgs/7980844269689605309.png
#
#                                                   text
# 0    a close up photo of herpes simplex skin condit...
# 1    a at distance photo of herpes simplex skin con...
# 2    a at distance photo of herpes simplex skin con...
# 3    a at distance photo of herpes simplex skin con...
# 4    a at distance photo of herpes simplex skin con...
# ..                                                 ...
# 432  a close up photo of folliculitis skin conditio...
# 433  a at an angle photo of folliculitis skin condi...
# 434  a close up photo of folliculitis skin conditio...
# 435  a at distance photo of folliculitis skin condi...
# 436  a close up photo of folliculitis skin conditio...
#
# [437 rows x 2 columns]

# %%
# !git clone https://github.com/danielgatis/rembg.git
# Out:
# Cloning into 'rembg'...
# remote: Enumerating objects: 2000, done.
# remote: Counting objects: 100% (2000/2000), done.
# remote: Compressing objects: 100% (853/853), done.
# remote: Total 2000 (delta 1201), reused 1749 (delta 1069), pack-reused 0
# Receiving objects: 100% (2000/2000), 62.70 MiB | 30.20 MiB/s, done.
# Resolving deltas: 100% (1201/1201), done.

# %%
import rembg.rembg.commands.s_
from PIL import Image

input_path = 'data/training_data/training_imgs/60032766606288611.png'
output_path = 'output.png'

input = Image.open(input_path)
output = remove(input)
output.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 7
#       4 input_path = 'data/training_data/training_imgs/60032766606288611.png'
#       5 output_path = 'output.png'
# ----> 7 input = Image.open(input_path)
#       8 output = remove(input)
#       9 output.save(output_path)
#
# File /opt/homebrew/lib/python3.11/site-packages/PIL/Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/training_data/training_imgs/60032766606288611.png'
